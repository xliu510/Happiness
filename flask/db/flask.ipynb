# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy.engine import reflection
from sqlalchemy import *
from sqlalchemy import Column, Integer, ForeignKey, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker, relationship
import pandas as pd

# %%
#engine = create_engine("sqlite:///../Resources/dow.sqlite")

engine = create_engine("sqlite:///../db/World_Happiness_Life_Expectancy_db.sqlite")

# %%
df_sql_select_all = pd.read_sql('SELECT * '
                            ' FROM World_Happiness_Report_2015_2016_2017_tb',engine)
df_sql_select_all.head(200)
# Out:
#      index                   Country                      Region_2015  \
# 0        0               Switzerland                   Western Europe
# 1        1                   Iceland                   Western Europe
# 2        2                   Denmark                   Western Europe
# 3        3                    Norway                   Western Europe
# 4        4                    Canada                    North America
# 5        5                   Finland                   Western Europe
# 6        6               Netherlands                   Western Europe
# 7        7                    Sweden                   Western Europe
# 8        8               New Zealand        Australia and New Zealand
# 9        9                 Australia        Australia and New Zealand
# 10      10                    Israel  Middle East and Northern Africa
# 11      11                Costa Rica      Latin America and Caribbean
# 12      12                   Austria                   Western Europe
# 13      13                    Mexico      Latin America and Caribbean
# 14      14             United States                    North America
# 15      15                    Brazil      Latin America and Caribbean
# 16      16                Luxembourg                   Western Europe
# 17      17                   Ireland                   Western Europe
# 18      18                   Belgium                   Western Europe
# 19      19      United Arab Emirates  Middle East and Northern Africa
# 20      20            United Kingdom                   Western Europe
# 21      21                      Oman  Middle East and Northern Africa
# 22      22                 Venezuela      Latin America and Caribbean
# 23      23                 Singapore                Southeastern Asia
# 24      24                    Panama      Latin America and Caribbean
# 25      25                   Germany                   Western Europe
# 26      26                     Chile      Latin America and Caribbean
# 27      27                     Qatar  Middle East and Northern Africa
# 28      28                    France                   Western Europe
# 29      29                 Argentina      Latin America and Caribbean
# ..     ...                       ...                              ...
# 128    128                   Myanmar                Southeastern Asia
# 129    129                   Georgia       Central and Eastern Europe
# 130    130                    Malawi               Sub-Saharan Africa
# 131    131                 Sri Lanka                    Southern Asia
# 132    132                  Cameroon               Sub-Saharan Africa
# 133    133                  Bulgaria       Central and Eastern Europe
# 134    134                     Egypt  Middle East and Northern Africa
# 135    135                     Yemen  Middle East and Northern Africa
# 136    136                    Angola               Sub-Saharan Africa
# 137    137                      Mali               Sub-Saharan Africa
# 138    138       Congo (Brazzaville)               Sub-Saharan Africa
# 139    139                   Comoros               Sub-Saharan Africa
# 140    140                    Uganda               Sub-Saharan Africa
# 141    141                   Senegal               Sub-Saharan Africa
# 142    142                     Gabon               Sub-Saharan Africa
# 143    143                     Niger               Sub-Saharan Africa
# 144    144                  Cambodia                Southeastern Asia
# 145    145                  Tanzania               Sub-Saharan Africa
# 146    146                Madagascar               Sub-Saharan Africa
# 147    147  Central African Republic               Sub-Saharan Africa
# 148    148                      Chad               Sub-Saharan Africa
# 149    149                    Guinea               Sub-Saharan Africa
# 150    150               Ivory Coast               Sub-Saharan Africa
# 151    151              Burkina Faso               Sub-Saharan Africa
# 152    152               Afghanistan                    Southern Asia
# 153    153                    Rwanda               Sub-Saharan Africa
# 154    154                     Benin               Sub-Saharan Africa
# 155    155                     Syria  Middle East and Northern Africa
# 156    156                   Burundi               Sub-Saharan Africa
# 157    157                      Togo               Sub-Saharan Africa
#
#      Happiness_Rank_2015  Happiness_Score_2015  Standard_Error_2015  \
# 0                      1                 7.587              0.03411
# 1                      2                 7.561              0.04884
# 2                      3                 7.527              0.03328
# 3                      4                 7.522              0.03880
# 4                      5                 7.427              0.03553
# 5                      6                 7.406              0.03140
# 6                      7                 7.378              0.02799
# 7                      8                 7.364              0.03157
# 8                      9                 7.286              0.03371
# 9                     10                 7.284              0.04083
# 10                    11                 7.278              0.03470
# 11                    12                 7.226              0.04454
# 12                    13                 7.200              0.03751
# 13                    14                 7.187              0.04176
# 14                    15                 7.119              0.03839
# 15                    16                 6.983              0.04076
# 16                    17                 6.946              0.03499
# 17                    18                 6.940              0.03676
# 18                    19                 6.937              0.03595
# 19                    20                 6.901              0.03729
# 20                    21                 6.867              0.01866
# 21                    22                 6.853              0.05335
# 22                    23                 6.810              0.06476
# 23                    24                 6.798              0.03780
# 24                    25                 6.786              0.04910
# 25                    26                 6.750              0.01848
# 26                    27                 6.670              0.05800
# 27                    28                 6.611              0.06257
# 28                    29                 6.575              0.03512
# 29                    30                 6.574              0.04612
# ..                   ...                   ...                  ...
# 128                  129                 4.307              0.04351
# 129                  130                 4.297              0.04221
# 130                  131                 4.292              0.06130
# 131                  132                 4.271              0.03751
# 132                  133                 4.252              0.04678
# 133                  134                 4.218              0.04828
# 134                  135                 4.194              0.03260
# 135                  136                 4.077              0.04367
# 136                  137                 4.033              0.04758
# 137                  138                 3.995              0.05602
# 138                  139                 3.989              0.06682
# 139                  140                 3.956              0.04797
# 140                  141                 3.931              0.04317
# 141                  142                 3.904              0.03608
# 142                  143                 3.896              0.04547
# 143                  144                 3.845              0.03602
# 144                  145                 3.819              0.05069
# 145                  146                 3.781              0.05061
# 146                  147                 3.681              0.03633
# 147                  148                 3.678              0.06112
# 148                  149                 3.667              0.03830
# 149                  150                 3.656              0.03590
# 150                  151                 3.655              0.05141
# 151                  152                 3.587              0.04324
# 152                  153                 3.575              0.03084
# 153                  154                 3.465              0.03464
# 154                  155                 3.340              0.03656
# 155                  156                 3.006              0.05015
# 156                  157                 2.905              0.08658
# 157                  158                 2.839              0.06727
#
#      GDP_per_Capita_2015  Family_2015  Health_2015  Freedom_2015  \
# 0                1.39651      1.34951      0.94143       0.66557
# 1                1.30232      1.40223      0.94784       0.62877
# 2                1.32548      1.36058      0.87464       0.64938
# 3                1.45900      1.33095      0.88521       0.66973
# 4                1.32629      1.32261      0.90563       0.63297
# 5                1.29025      1.31826      0.88911       0.64169
# 6                1.32944      1.28017      0.89284       0.61576
# 7                1.33171      1.28907      0.91087       0.65980
# 8                1.25018      1.31967      0.90837       0.63938
# 9                1.33358      1.30923      0.93156       0.65124
# 10               1.22857      1.22393      0.91387       0.41319
# 11               0.95578      1.23788      0.86027       0.63376
# 12               1.33723      1.29704      0.89042       0.62433
# 13               1.02054      0.91451      0.81444       0.48181
# 14               1.39451      1.24711      0.86179       0.54604
# 15               0.98124      1.23287      0.69702       0.49049
# 16               1.56391      1.21963      0.91894       0.61583
# 17               1.33596      1.36948      0.89533       0.61777
# 18               1.30782      1.28566      0.89667       0.58450
# 19               1.42727      1.12575      0.80925       0.64157
# 20               1.26637      1.28548      0.90943       0.59625
# 21               1.36011      1.08182      0.76276       0.63274
# 22               1.04424      1.25596      0.72052       0.42908
# 23               1.52186      1.02000      1.02525       0.54252
# 24               1.06353      1.19850      0.79661       0.54210
# 25               1.32792      1.29937      0.89186       0.61477
# 26               1.10715      1.12447      0.85857       0.44132
# 27               1.69042      1.07860      0.79733       0.64040
# 28               1.27778      1.26038      0.94579       0.55011
# 29               1.05351      1.24823      0.78723       0.44974
# ..                   ...          ...          ...           ...
# 128              0.27108      0.70905      0.48246       0.44017
# 129              0.74190      0.38562      0.72926       0.40577
# 130              0.01604      0.41134      0.22562       0.43054
# 131              0.83524      1.01905      0.70806       0.53726
# 132              0.42250      0.88767      0.23402       0.49309
# 133              1.01216      1.10614      0.76649       0.30587
# 134              0.88180      0.74700      0.61712       0.17288
# 135              0.54649      0.68093      0.40064       0.35571
# 136              0.75778      0.86040      0.16683       0.10384
# 137              0.26074      1.03526      0.20583       0.38857
# 138              0.67866      0.66290      0.31051       0.41466
# 139              0.23906      0.79273      0.36315       0.22917
# 140              0.21102      1.13299      0.33861       0.45727
# 141              0.36498      0.97619      0.43540       0.36772
# 142              1.06024      0.90528      0.43372       0.31914
# 143              0.06940      0.77265      0.29707       0.47692
# 144              0.46038      0.62736      0.61114       0.66246
# 145              0.28520      1.00268      0.38215       0.32878
# 146              0.20824      0.66801      0.46721       0.19184
# 147              0.07850      0.00000      0.06699       0.48879
# 148              0.34193      0.76062      0.15010       0.23501
# 149              0.17417      0.46475      0.24009       0.37725
# 150              0.46534      0.77115      0.15185       0.46866
# 151              0.25812      0.85188      0.27125       0.39493
# 152              0.31982      0.30285      0.30335       0.23414
# 153              0.22208      0.77370      0.42864       0.59201
# 154              0.28665      0.35386      0.31910       0.48450
# 155              0.66320      0.47489      0.72193       0.15684
# 156              0.01530      0.41587      0.22396       0.11850
# 157              0.20868      0.13995      0.28443       0.36453
#
#               ...            Happiness_Score_2017  Whisker_high_2017  \
# 0             ...                           7.494           7.561772
# 1             ...                           7.504           7.622030
# 2             ...                           7.522           7.581728
# 3             ...                           7.537           7.594445
# 4             ...                           7.316           7.384403
# 5             ...                           7.469           7.527542
# 6             ...                           7.377           7.427426
# 7             ...                           7.284           7.344095
# 8             ...                           7.314           7.379510
# 9             ...                           7.284           7.356651
# 10            ...                           7.213           7.279853
# 11            ...                           7.079           7.168112
# 12            ...                           7.006           7.070670
# 13            ...                           6.578           6.671149
# 14            ...                           6.993           7.074657
# 15            ...                           6.635           6.725470
# 16            ...                           6.863           6.923686
# 17            ...                           6.977           7.043352
# 18            ...                           6.891           6.955821
# 19            ...                           6.648           6.722047
# 20            ...                           6.714           6.783792
# 21            ...                             NaN                NaN
# 22            ...                           5.250           5.370032
# 23            ...                           6.572           6.636723
# 24            ...                           6.452           6.557131
# 25            ...                           6.951           7.005382
# 26            ...                           6.652           6.739251
# 27            ...                           6.375           6.568477
# 28            ...                           6.442           6.515768
# 29            ...                           6.599           6.690085
# ..            ...                             ...                ...
# 128           ...                           4.545           4.614740
# 129           ...                           4.286           4.374934
# 130           ...                           3.970           4.077479
# 131           ...                           4.440           4.553447
# 132           ...                           4.695           4.796541
# 133           ...                           4.714           4.803695
# 134           ...                           4.735           4.825134
# 135           ...                           3.593           3.692750
# 136           ...                           3.795           3.951642
# 137           ...                           4.190           4.269671
# 138           ...                           4.291           4.410054
# 139           ...                             NaN                NaN
# 140           ...                           4.081           4.195800
# 141           ...                           4.535           4.601604
# 142           ...                           4.465           4.557362
# 143           ...                           4.028           4.111947
# 144           ...                           4.168           4.278518
# 145           ...                           3.349           3.461430
# 146           ...                           3.644           3.714319
# 147           ...                           2.693           2.864884
# 148           ...                           3.936           4.034712
# 149           ...                           3.507           3.584428
# 150           ...                           4.180           4.275183
# 151           ...                           4.032           4.124059
# 152           ...                           3.794           3.873661
# 153           ...                           3.471           3.543030
# 154           ...                           3.657           3.745784
# 155           ...                           3.462           3.663669
# 156           ...                           2.905           3.074690
# 157           ...                           3.495           3.594038
#
#      Whisker_low_2017 GDP_per_Capita_2017  Family_2017  Health_2017  \
# 0            7.426227            1.564980     1.516912     0.858131
# 1            7.385970            1.480633     1.610574     0.833552
# 2            7.462272            1.482383     1.551122     0.792566
# 3            7.479556            1.616463     1.533524     0.796667
# 4            7.247597            1.479204     1.481349     0.834558
# 5            7.410458            1.443572     1.540247     0.809158
# 6            7.326574            1.503945     1.428939     0.810696
# 7            7.223905            1.494387     1.478162     0.830875
# 8            7.248490            1.405706     1.548195     0.816760
# 9            7.211349            1.484415     1.510042     0.843887
# 10           7.146146            1.375382     1.376290     0.838404
# 11           6.989888            1.109706     1.416404     0.759509
# 12           6.941330            1.487097     1.459945     0.815328
# 13           6.484851            1.153184     1.210862     0.709979
# 14           6.911343            1.546259     1.419921     0.774287
# 15           6.544531            1.107353     1.431306     0.616552
# 16           6.802314            1.741944     1.457584     0.845089
# 17           6.910649            1.535707     1.558231     0.809783
# 18           6.826179            1.463781     1.462313     0.818092
# 19           6.573952            1.626343     1.266410     0.726798
# 20           6.644209            1.441634     1.496460     0.805336
# 21                NaN                 NaN          NaN          NaN
# 22           5.129968            1.128431     1.431338     0.617144
# 23           6.507277            1.692278     1.353814     0.949492
# 24           6.346870            1.233748     1.373193     0.706156
# 25           6.896619            1.487923     1.472520     0.798951
# 26           6.564749            1.252785     1.284025     0.819480
# 27           6.181523            1.870766     1.274297     0.710098
# 28           6.368232            1.430923     1.387777     0.844466
# 29           6.507915            1.185295     1.440451     0.695137
# ..                ...                 ...          ...          ...
# 128          4.475260            0.367111     1.123236     0.397523
# 129          4.197066            0.950613     0.570615     0.649547
# 130          3.862521            0.233442     0.512569     0.315090
# 131          4.326553            1.009850     1.259976     0.625131
# 132          4.593459            0.564305     0.946018     0.132892
# 133          4.624306            1.161459     1.434379     0.708218
# 134          4.644866            0.989702     0.997471     0.520187
# 135          3.493250            0.591683     0.935382     0.310081
# 136          3.638358            0.858428     1.104412     0.049869
# 137          4.110329            0.476180     1.281473     0.169366
# 138          4.171946            0.808964     0.832044     0.289957
# 139               NaN                 NaN          NaN          NaN
# 140          3.966200            0.381431     1.129828     0.217633
# 141          4.468396            0.479309     1.179692     0.409363
# 142          4.372639            1.198210     1.155620     0.356579
# 143          3.944053            0.161925     0.993025     0.268505
# 144          4.057483            0.601765     1.006238     0.429783
# 145          3.236570            0.511136     1.041990     0.364509
# 146          3.573681            0.305809     0.913020     0.375223
# 147          2.521116            0.000000     0.000000     0.018773
# 148          3.837289            0.438013     0.953856     0.041135
# 149          3.429572            0.244550     0.791245     0.194129
# 150          4.084817            0.603049     0.904780     0.048642
# 151          3.939941            0.350228     1.043280     0.215844
# 152          3.714338            0.401477     0.581543     0.180747
# 153          3.398970            0.368746     0.945707     0.326425
# 154          3.568217            0.431085     0.435300     0.209930
# 155          3.260331            0.777153     0.396103     0.500533
# 156          2.735310            0.091623     0.629794     0.151611
# 157          3.395962            0.305445     0.431883     0.247106
#
#      Freedom_2017  Generosity_2017  Government_Trust_2017  \
# 0        0.620071         0.290549               0.367007
# 1        0.627163         0.475540               0.153527
# 2        0.626007         0.355280               0.400770
# 3        0.635423         0.362012               0.315964
# 4        0.611101         0.435540               0.287372
# 5        0.617951         0.245483               0.382612
# 6        0.585384         0.470490               0.282662
# 7        0.612924         0.385399               0.384399
# 8        0.614062         0.500005               0.382817
# 9        0.601607         0.477699               0.301184
# 10       0.405989         0.330083               0.085242
# 11       0.580132         0.214613               0.100107
# 12       0.567766         0.316472               0.221060
# 13       0.412730         0.120990               0.132774
# 14       0.505741         0.392579               0.135639
# 15       0.437454         0.162350               0.111093
# 16       0.596628         0.283181               0.318834
# 17       0.573110         0.427858               0.298388
# 18       0.539771         0.231503               0.251343
# 19       0.608345         0.360942               0.324490
# 20       0.508190         0.492774               0.265428
# 21            NaN              NaN                    NaN
# 22       0.153997         0.065020               0.064491
# 23       0.549841         0.345966               0.464308
# 24       0.550027         0.210557               0.070984
# 25       0.562511         0.336269               0.276732
# 26       0.376895         0.326662               0.082288
# 27       0.604131         0.330474               0.439299
# 28       0.470222         0.129762               0.172502
# 29       0.494519         0.109457               0.059740
# ..            ...              ...                    ...
# 128      0.514492         0.838075               0.188816
# 129      0.309410         0.054009               0.251667
# 130      0.466915         0.287170               0.072712
# 131      0.561213         0.490864               0.073654
# 132      0.430389         0.236298               0.051307
# 133      0.289232         0.113178               0.011052
# 134      0.282110         0.128631               0.114381
# 135      0.249464         0.104125               0.056767
# 136      0.000000         0.097926               0.069720
# 137      0.306614         0.183354               0.104970
# 138      0.435026         0.120852               0.079618
# 139           NaN              NaN                    NaN
# 140      0.443186         0.325766               0.057070
# 141      0.377922         0.183469               0.115460
# 142      0.312329         0.043785               0.076047
# 143      0.363659         0.228674               0.138573
# 144      0.633376         0.385923               0.068106
# 145      0.390018         0.354256               0.066035
# 146      0.189197         0.208733               0.067232
# 147      0.270842         0.280876               0.056565
# 148      0.162342         0.216114               0.053582
# 149      0.348588         0.264815               0.110938
# 150      0.447706         0.201237               0.130062
# 151      0.324368         0.250865               0.120328
# 152      0.106180         0.311871               0.061158
# 153      0.581844         0.252756               0.455220
# 154      0.425963         0.207948               0.060929
# 155      0.081539         0.493664               0.151347
# 156      0.059901         0.204435               0.084148
# 157      0.380426         0.196896               0.095665
#
#      Dystopia_Residual_2017
# 0                  2.276716
# 1                  2.322715
# 2                  2.313707
# 3                  2.277027
# 4                  2.187264
# 5                  2.430182
# 6                  2.294804
# 7                  2.097538
# 8                  2.046456
# 9                  2.065211
# 10                 2.801757
# 11                 2.898639
# 12                 2.138506
# 13                 2.837155
# 14                 2.218113
# 15                 2.769267
# 16                 1.619512
# 17                 1.773869
# 18                 2.124210
# 19                 1.734704
# 20                 1.704144
# 21                      NaN
# 22                 1.789464
# 23                 1.216362
# 24                 2.307200
# 25                 2.015770
# 26                 2.509586
# 27                 1.145464
# 28                 2.005955
# 29                 2.614005
# ..                      ...
# 128                1.115290
# 129                1.500138
# 130                2.081786
# 131                0.419389
# 132                2.333646
# 133                0.996139
# 134                1.702161
# 135                1.345601
# 136                1.614482
# 137                1.668191
# 138                1.724136
# 139                     NaN
# 140                1.526363
# 141                1.789646
# 142                1.322916
# 143                1.873983
# 144                1.042941
# 145                0.621130
# 146                1.584613
# 147                2.066005
# 148                2.071238
# 149                1.552312
# 150                1.844964
# 151                1.727213
# 152                2.150801
# 153                0.540061
# 154                1.885631
# 155                1.061574
# 156                1.683024
# 157                1.837229
#
# [158 rows x 36 columns]

# %%
life_df = pd.read_sql('SELECT * FROM weekly_hours_avg_worked_job_df_2015_2017_tb', engine)
life_df.head(100)
# Out:
#     index    Country          Sex       Age     Employment_status  \
# 0      15  Australia  All persons  15 to 24  Dependent employment
# 1      16  Australia  All persons  15 to 24  Dependent employment
# 2      32  Australia  All persons  15 to 24  Dependent employment
# 3      33  Australia  All persons  15 to 24  Dependent employment
# 4      49  Australia  All persons  15 to 24  Dependent employment
# 5      50  Australia  All persons  15 to 24  Dependent employment
# 6      66  Australia  All persons  15 to 24      Total employment
# 7      67  Australia  All persons  15 to 24      Total employment
# 8      83  Australia  All persons  15 to 24      Total employment
# 9      84  Australia  All persons  15 to 24      Total employment
# 10    100  Australia  All persons  15 to 24      Total employment
# 11    101  Australia  All persons  15 to 24      Total employment
# 12    117  Australia  All persons  25 to 54  Dependent employment
# 13    118  Australia  All persons  25 to 54  Dependent employment
# 14    134  Australia  All persons  25 to 54  Dependent employment
# 15    135  Australia  All persons  25 to 54  Dependent employment
# 16    151  Australia  All persons  25 to 54  Dependent employment
# 17    152  Australia  All persons  25 to 54  Dependent employment
# 18    168  Australia  All persons  25 to 54      Total employment
# 19    169  Australia  All persons  25 to 54      Total employment
# 20    185  Australia  All persons  25 to 54      Total employment
# 21    186  Australia  All persons  25 to 54      Total employment
# 22    202  Australia  All persons  25 to 54      Total employment
# 23    203  Australia  All persons  25 to 54      Total employment
# 24    219  Australia  All persons  55 to 64  Dependent employment
# 25    220  Australia  All persons  55 to 64  Dependent employment
# 26    236  Australia  All persons  55 to 64  Dependent employment
# 27    237  Australia  All persons  55 to 64  Dependent employment
# 28    253  Australia  All persons  55 to 64  Dependent employment
# 29    254  Australia  All persons  55 to 64  Dependent employment
# ..    ...        ...          ...       ...                   ...
# 70    610  Australia          Men  15 to 24      Total employment
# 71    611  Australia          Men  15 to 24      Total employment
# 72    627  Australia          Men  25 to 54  Dependent employment
# 73    628  Australia          Men  25 to 54  Dependent employment
# 74    644  Australia          Men  25 to 54  Dependent employment
# 75    645  Australia          Men  25 to 54  Dependent employment
# 76    661  Australia          Men  25 to 54  Dependent employment
# 77    662  Australia          Men  25 to 54  Dependent employment
# 78    678  Australia          Men  25 to 54      Total employment
# 79    679  Australia          Men  25 to 54      Total employment
# 80    695  Australia          Men  25 to 54      Total employment
# 81    696  Australia          Men  25 to 54      Total employment
# 82    712  Australia          Men  25 to 54      Total employment
# 83    713  Australia          Men  25 to 54      Total employment
# 84    729  Australia          Men  55 to 64  Dependent employment
# 85    730  Australia          Men  55 to 64  Dependent employment
# 86    746  Australia          Men  55 to 64  Dependent employment
# 87    747  Australia          Men  55 to 64  Dependent employment
# 88    763  Australia          Men  55 to 64  Dependent employment
# 89    764  Australia          Men  55 to 64  Dependent employment
# 90    780  Australia          Men  55 to 64      Total employment
# 91    781  Australia          Men  55 to 64      Total employment
# 92    797  Australia          Men  55 to 64      Total employment
# 93    798  Australia          Men  55 to 64      Total employment
# 94    814  Australia          Men  55 to 64      Total employment
# 95    815  Australia          Men  55 to 64      Total employment
# 96    831  Australia          Men       65+  Dependent employment
# 97    832  Australia          Men       65+  Dependent employment
# 98    848  Australia          Men       65+  Dependent employment
# 99    849  Australia          Men       65+  Dependent employment
#
#                      Job_type Frequency  TIME Unit_Code   Unit  \
# 0        Full-time employment    Annual  2016      HOUR  Hours
# 1        Full-time employment    Annual  2017      HOUR  Hours
# 2        Part-time employment    Annual  2016      HOUR  Hours
# 3        Part-time employment    Annual  2017      HOUR  Hours
# 4   Total declared employment    Annual  2016      HOUR  Hours
# 5   Total declared employment    Annual  2017      HOUR  Hours
# 6        Full-time employment    Annual  2016      HOUR  Hours
# 7        Full-time employment    Annual  2017      HOUR  Hours
# 8        Part-time employment    Annual  2016      HOUR  Hours
# 9        Part-time employment    Annual  2017      HOUR  Hours
# 10  Total declared employment    Annual  2016      HOUR  Hours
# 11  Total declared employment    Annual  2017      HOUR  Hours
# 12       Full-time employment    Annual  2016      HOUR  Hours
# 13       Full-time employment    Annual  2017      HOUR  Hours
# 14       Part-time employment    Annual  2016      HOUR  Hours
# 15       Part-time employment    Annual  2017      HOUR  Hours
# 16  Total declared employment    Annual  2016      HOUR  Hours
# 17  Total declared employment    Annual  2017      HOUR  Hours
# 18       Full-time employment    Annual  2016      HOUR  Hours
# 19       Full-time employment    Annual  2017      HOUR  Hours
# 20       Part-time employment    Annual  2016      HOUR  Hours
# 21       Part-time employment    Annual  2017      HOUR  Hours
# 22  Total declared employment    Annual  2016      HOUR  Hours
# 23  Total declared employment    Annual  2017      HOUR  Hours
# 24       Full-time employment    Annual  2016      HOUR  Hours
# 25       Full-time employment    Annual  2017      HOUR  Hours
# 26       Part-time employment    Annual  2016      HOUR  Hours
# 27       Part-time employment    Annual  2017      HOUR  Hours
# 28  Total declared employment    Annual  2016      HOUR  Hours
# 29  Total declared employment    Annual  2017      HOUR  Hours
# ..                        ...       ...   ...       ...    ...
# 70  Total declared employment    Annual  2016      HOUR  Hours
# 71  Total declared employment    Annual  2017      HOUR  Hours
# 72       Full-time employment    Annual  2016      HOUR  Hours
# 73       Full-time employment    Annual  2017      HOUR  Hours
# 74       Part-time employment    Annual  2016      HOUR  Hours
# 75       Part-time employment    Annual  2017      HOUR  Hours
# 76  Total declared employment    Annual  2016      HOUR  Hours
# 77  Total declared employment    Annual  2017      HOUR  Hours
# 78       Full-time employment    Annual  2016      HOUR  Hours
# 79       Full-time employment    Annual  2017      HOUR  Hours
# 80       Part-time employment    Annual  2016      HOUR  Hours
# 81       Part-time employment    Annual  2017      HOUR  Hours
# 82  Total declared employment    Annual  2016      HOUR  Hours
# 83  Total declared employment    Annual  2017      HOUR  Hours
# 84       Full-time employment    Annual  2016      HOUR  Hours
# 85       Full-time employment    Annual  2017      HOUR  Hours
# 86       Part-time employment    Annual  2016      HOUR  Hours
# 87       Part-time employment    Annual  2017      HOUR  Hours
# 88  Total declared employment    Annual  2016      HOUR  Hours
# 89  Total declared employment    Annual  2017      HOUR  Hours
# 90       Full-time employment    Annual  2016      HOUR  Hours
# 91       Full-time employment    Annual  2017      HOUR  Hours
# 92       Part-time employment    Annual  2016      HOUR  Hours
# 93       Part-time employment    Annual  2017      HOUR  Hours
# 94  Total declared employment    Annual  2016      HOUR  Hours
# 95  Total declared employment    Annual  2017      HOUR  Hours
# 96       Full-time employment    Annual  2016      HOUR  Hours
# 97       Full-time employment    Annual  2017      HOUR  Hours
# 98       Part-time employment    Annual  2016      HOUR  Hours
# 99       Part-time employment    Annual  2017      HOUR  Hours
#
#     PowerCode_Code PowerCode Reference_Period_Code Reference_Period  \
# 0                0     Units                  None             None
# 1                0     Units                  None             None
# 2                0     Units                  None             None
# 3                0     Units                  None             None
# 4                0     Units                  None             None
# 5                0     Units                  None             None
# 6                0     Units                  None             None
# 7                0     Units                  None             None
# 8                0     Units                  None             None
# 9                0     Units                  None             None
# 10               0     Units                  None             None
# 11               0     Units                  None             None
# 12               0     Units                  None             None
# 13               0     Units                  None             None
# 14               0     Units                  None             None
# 15               0     Units                  None             None
# 16               0     Units                  None             None
# 17               0     Units                  None             None
# 18               0     Units                  None             None
# 19               0     Units                  None             None
# 20               0     Units                  None             None
# 21               0     Units                  None             None
# 22               0     Units                  None             None
# 23               0     Units                  None             None
# 24               0     Units                  None             None
# 25               0     Units                  None             None
# 26               0     Units                  None             None
# 27               0     Units                  None             None
# 28               0     Units                  None             None
# 29               0     Units                  None             None
# ..             ...       ...                   ...              ...
# 70               0     Units                  None             None
# 71               0     Units                  None             None
# 72               0     Units                  None             None
# 73               0     Units                  None             None
# 74               0     Units                  None             None
# 75               0     Units                  None             None
# 76               0     Units                  None             None
# 77               0     Units                  None             None
# 78               0     Units                  None             None
# 79               0     Units                  None             None
# 80               0     Units                  None             None
# 81               0     Units                  None             None
# 82               0     Units                  None             None
# 83               0     Units                  None             None
# 84               0     Units                  None             None
# 85               0     Units                  None             None
# 86               0     Units                  None             None
# 87               0     Units                  None             None
# 88               0     Units                  None             None
# 89               0     Units                  None             None
# 90               0     Units                  None             None
# 91               0     Units                  None             None
# 92               0     Units                  None             None
# 93               0     Units                  None             None
# 94               0     Units                  None             None
# 95               0     Units                  None             None
# 96               0     Units                  None             None
# 97               0     Units                  None             None
# 98               0     Units                  None             None
# 99               0     Units                  None             None
#
#         Value Flag_Codes Flags
# 0   39.670223       None  None
# 1   39.674686       None  None
# 2   14.072064       None  None
# 3   14.163016       None  None
# 4   27.112830       None  None
# 5   26.995636       None  None
# 6   39.784423       None  None
# 7   39.781886       None  None
# 8   14.011416       None  None
# 9   14.085993       None  None
# 10  27.164749       None  None
# 11  27.002973       None  None
# 12  42.329405       None  None
# 13  42.183939       None  None
# 14  18.707076       None  None
# 15  18.786573       None  None
# 16  37.971525       None  None
# 17  37.925827       None  None
# 18  42.687012       None  None
# 19  42.527372       None  None
# 20  18.265814       None  None
# 21  18.411545       None  None
# 22  37.963251       None  None
# 23  37.919060       None  None
# 24  42.358108       None  None
# 25  42.320321       None  None
# 26  18.141720       None  None
# 27  18.363187       None  None
# 28  36.512099       None  None
# 29  36.851653       None  None
# ..        ...        ...   ...
# 70  29.262136       None  None
# 71  29.261280       None  None
# 72  43.985778       None  None
# 73  43.869416       None  None
# 74  18.512871       None  None
# 75  18.408151       None  None
# 76  42.187833       None  None
# 77  42.082475       None  None
# 78  44.337334       None  None
# 79  44.237555       None  None
# 80  18.341392       None  None
# 81  18.357496       None  None
# 82  42.331161       None  None
# 83  42.201679       None  None
# 84  44.177277       None  None
# 85  44.048616       None  None
# 86  17.687209       None  None
# 87  17.866484       None  None
# 88  41.014264       None  None
# 89  41.383891       None  None
# 90  44.793375       None  None
# 91  44.630003       None  None
# 92  17.325924       None  None
# 93  17.579027       None  None
# 94  40.987919       None  None
# 95  41.267873       None  None
# 96  43.595678       None  None
# 97  44.267730       None  None
# 98  15.277779       None  None
# 99  14.839237       None  None
#
# [100 rows x 17 columns]

# %%
df_sql_select = pd.read_sql('SELECT Happiness_Score_2015, Freedom_2015 '
                            'FROM World_Happiness_Life_Expectancy_tb',engine)

# %%
df_sql_select.head()
# Out:
#    Happiness_Score_2015  Freedom_2015
# 0                 7.587       0.66557
# 1                 7.561       0.62877
# 2                 7.527       0.64938
# 3                 7.522       0.66973
# 4                 7.427       0.63297

# %%
selected_feature = 'Freedom_2015'
happiness_2015_x = df_sql_select["Happiness_Score_2015"].values.tolist()
happiness_2015_y = df_sql_select[selected_feature].values.tolist()

# %%
avg_happiness_region_select = ('SELECT region_2015, avg(happiness_score_2015) as avg_happiness_2015 '
                               ', avg(life_expectancy) as avg_life_2015 '
                               ', avg(hw.value) as avg_whr_2015 '
                              'FROM World_Happiness_Life_Expectancy_tb hl'
                               ' JOIN weekly_hours_avg_worked_job_df_2015_2017_tb hw ON hl.country = hw.country '
                              'GROUP BY region_2015')
avg_happiness_region_df = pd.read_sql(avg_happiness_region_select, engine)
avg_happiness_region_df.head(20)
# Out:
#                        Region_2015  avg_happiness_2015  avg_life_2015  \
# 0        Australia and New Zealand            7.285000      82.200000
# 1       Central and Eastern Europe            5.466500      77.850000
# 2      Latin America and Caribbean            6.890000      79.025000
# 3  Middle East and Northern Africa            6.305000      79.150000
# 4               Sub-Saharan Africa            4.642000      62.900000
# 5                   Western Europe            6.778725      82.123024
#
#    avg_whr_2015
# 0     30.859099
# 1     31.820370
# 2     35.498074
# 3     35.697025
# 4     35.043157
# 5     30.008952

# %%
happiness_region = avg_happiness_region_df["Region_2015"].values.tolist()
happiness_score = avg_happiness_region_df["avg_happiness_2015"].values.tolist()
happiness_life = avg_happiness_region_df["avg_life_2015"].values.tolist()
happiness_work = avg_happiness_region_df["avg_whr_2015"].values.tolist()
happiness = {
    "region": happiness_region,
    "happiness": happiness_score,
    "life": happiness_life,
    "work": happiness_work
}
happiness
# Out:
# {'region': ['Australia and New Zealand',
#   'Central and Eastern Europe',
#   'Latin America and Caribbean',
#   'Middle East and Northern Africa',
#   'Sub-Saharan Africa',
#   'Western Europe'],
#  'happiness': [7.285000000000048,
#   5.466500000000076,
#   6.889999999999965,
#   6.305000000000034,
#   4.642000000000018,
#   6.778724887815017],
#  'life': [82.19999999999976,
#   77.85000000000022,
#   79.02500000000097,
#   79.14999999999964,
#   62.8999999999998,
#   82.12302381774192],
#  'work': [30.859099184987908,
#   31.820369531303765,
#   35.498074041039466,
#   35.697025238673916,
#   35.04315742750006,
#   30.0089524004267]}

# %%
city_sql = ('SELECT city, bikes_available, time '
           #', ROW_NUMBER () OVER (PARTITION BY station_id ORDER BY COUNT(time) DESC) AS RowNum '
           'FROM status '
           'JOIN station ON status.station_id = station.id ')
           #'GROUP BY city, bikes_available ')
           #'WHERE RowNum = 1'
           #'ORDER BY bikes_available, row_ct DESC')

top_city_df2 = pd.read_sql(city_sql, engine.connect())

# %%
top_city_df2.head()
# Out:
#        city  bikes_available                 time
# 0  San Jose                2  2013/08/29 12:06:01
# 1  San Jose                2  2013/08/29 12:07:01
# 2  San Jose                2  2013/08/29 12:08:01
# 3  San Jose                2  2013/08/29 12:09:01
# 4  San Jose                2  2013/08/29 12:10:01

# %%
top_city_df2['time'] = pd.to_datetime(top_city_df2['time'])

# %%
top_city_df2['hour'] = top_city_df2['time'].dt.hour

# %%
top_city_df2.head()
# Out:
#        city  bikes_available                time  hour
# 0  San Jose                2 2013-08-29 12:06:01    12
# 1  San Jose                2 2013-08-29 12:07:01    12
# 2  San Jose                2 2013-08-29 12:08:01    12
# 3  San Jose                2 2013-08-29 12:09:01    12
# 4  San Jose                2 2013-08-29 12:10:01    12

# %%
top_city_gb = top_city_df2.groupby(['city', 'hour'])['bikes_available'].mean().unstack(level=1)

# %%
top_city_gb.head()
# Out:
# city           hour
# Mountain View  0       8.050587
#                1       8.049645
#                2       8.051955
#                3       8.053251
#                4       8.054365
# Name: bikes_available, dtype: float64

# %%
top_sql = ('SELECT city, bikes_available, COUNT(time) AS row_ct '
           #', ROW_NUMBER () OVER (PARTITION BY station_id ORDER BY COUNT(time) DESC) AS RowNum '
           'FROM status '
           'JOIN station ON status.station_id = station.id '
           'GROUP BY city, bikes_available ')
           #'WHERE RowNum = 1'
           #'ORDER BY bikes_available, row_ct DESC')

top_city = pd.read_sql(top_sql, engine.connect())

# %%
top_city_df = top_city

# %%
top_city_df[''] = top_city_df.groupby([''])

# %%
top_city_df.head(5)
# Out:
#             city  bikes_available  row_ct
# 0  Mountain View                0   24238
# 1  Mountain View                1   73510
# 2  Mountain View                2  159560
# 3  Mountain View                3  290038
# 4  Mountain View                4  475999

# %%
top_busiest = top_city_df.loc[top_city_df['bikes_available'] == 0]

# %%
top_busiest
# Out:
#               city  bikes_available  row_ct
# 0    Mountain View                0   24238
# 24       Palo Alto                0    5478
# 45    Redwood City                0    6378
# 72   San Francisco                0  454321
# 100       San Jose                0   38589

# %%
top_city_df['top_Rank'] = avg_city.groupby(['city', 'yr'])[''].rank(ascending=False)

# %%
year_extract = '201'
avg_sql = (f'SELECT city, substr(start_date, INSTR(start_date, {year_extract}), 4) as yr, avg(duration) as avg_trip '
           'FROM trip '
           'JOIN station ON trip.start_station_id = station.id '
           'GROUP BY city, yr'
          )

avg_city = pd.read_sql(avg_sql, engine.connect())

# %%
avg_city['avg_trip'] = avg_city['avg_trip']/60

# %%
##clean up

# %%
avg_city['avg_trip'] = avg_city['avg_trip'].round()
avg_city
# Out:
#              city    yr  avg_trip
# 0   Mountain View  2013      47.0
# 1   Mountain View  2014      29.0
# 2   Mountain View  2015      27.0
# 3       Palo Alto  2013      83.0
# 4       Palo Alto  2014      62.0
# 5       Palo Alto  2015      79.0
# 6    Redwood City  2013      39.0
# 7    Redwood City  2014      52.0
# 8    Redwood City  2015      34.0
# 9   San Francisco  2013      20.0
# 10  San Francisco  2014      18.0
# 11  San Francisco  2015      15.0
# 12       San Jose  2013      25.0
# 13       San Jose  2014      22.0
# 14       San Jose  2015      23.0

# %%
avg_list = avg_city.to_dict('records')
avg_list
# Out:
# [{'city': 'Mountain View', 'yr': '2013', 'avg_trip': 47.0},
#  {'city': 'Mountain View', 'yr': '2014', 'avg_trip': 29.0},
#  {'city': 'Mountain View', 'yr': '2015', 'avg_trip': 27.0},
#  {'city': 'Palo Alto', 'yr': '2013', 'avg_trip': 83.0},
#  {'city': 'Palo Alto', 'yr': '2014', 'avg_trip': 62.0},
#  {'city': 'Palo Alto', 'yr': '2015', 'avg_trip': 79.0},
#  {'city': 'Redwood City', 'yr': '2013', 'avg_trip': 39.0},
#  {'city': 'Redwood City', 'yr': '2014', 'avg_trip': 52.0},
#  {'city': 'Redwood City', 'yr': '2015', 'avg_trip': 34.0},
#  {'city': 'San Francisco', 'yr': '2013', 'avg_trip': 20.0},
#  {'city': 'San Francisco', 'yr': '2014', 'avg_trip': 18.0},
#  {'city': 'San Francisco', 'yr': '2015', 'avg_trip': 15.0},
#  {'city': 'San Jose', 'yr': '2013', 'avg_trip': 25.0},
#  {'city': 'San Jose', 'yr': '2014', 'avg_trip': 22.0},
#  {'city': 'San Jose', 'yr': '2015', 'avg_trip': 23.0}]

# %%
yr_2013 = []
yr_2014 = []
yr_2015 = []
for item in avg_list:
    data = {}
    for k,v in item.items():
        if(k=='city'):
            data['axis'] = v
        if(k=='avg_trip'):
            data['value'] = v
        if(k=='yr'and v=='2013'):
            data['name'] = v
            yr_2013.append(data)
        elif(k=='yr'and v=='2014'):
            data['name'] = v
            yr_2014.append(data)
        elif(k=='yr'and v=='2015'):
            data['name'] = v
            yr_2015.append(data)

# %%
all_yr = [yr_2013, yr_2014, yr_2015]

# %%
all_yr
# Out:
# [[{'axis': 'Mountain View', 'name': '2013', 'value': 47.0},
#   {'axis': 'Palo Alto', 'name': '2013', 'value': 83.0},
#   {'axis': 'Redwood City', 'name': '2013', 'value': 39.0},
#   {'axis': 'San Francisco', 'name': '2013', 'value': 20.0},
#   {'axis': 'San Jose', 'name': '2013', 'value': 25.0}],
#  [{'axis': 'Mountain View', 'name': '2014', 'value': 29.0},
#   {'axis': 'Palo Alto', 'name': '2014', 'value': 62.0},
#   {'axis': 'Redwood City', 'name': '2014', 'value': 52.0},
#   {'axis': 'San Francisco', 'name': '2014', 'value': 18.0},
#   {'axis': 'San Jose', 'name': '2014', 'value': 22.0}],
#  [{'axis': 'Mountain View', 'name': '2015', 'value': 27.0},
#   {'axis': 'Palo Alto', 'name': '2015', 'value': 79.0},
#   {'axis': 'Redwood City', 'name': '2015', 'value': 34.0},
#   {'axis': 'San Francisco', 'name': '2015', 'value': 15.0},
#   {'axis': 'San Jose', 'name': '2015', 'value': 23.0}]]

# %%
year_extract = '201'
avg_station_sql = (f'SELECT city, name, substr(start_date, INSTR(start_date, {year_extract}), 4) as yr, ' +
                'avg(duration) as avg_trip ' +
                'FROM trip ' +
                'JOIN station ON trip.start_station_id = station.id ' +
                'GROUP BY city, name, yr'
            )

avg_station = pd.read_sql(avg_station_sql, engine.connect())

# %%
avg_station.head()
# Out:
#             city                              name    yr     avg_trip
# 0  Mountain View  Castro Street and El Camino Real  2014  1830.964374
# 1  Mountain View  Castro Street and El Camino Real  2015  1922.758454
# 2  Mountain View              Evelyn Park and Ride  2013  1004.867550
# 3  Mountain View              Evelyn Park and Ride  2014  1212.192265
# 4  Mountain View              Evelyn Park and Ride  2015  1066.955810

# %%
avg_station['avg_trip'] = avg_station['avg_trip']/60
avg_station['avg_trip'] = avg_station['avg_trip'].round()

# %%
avg_station_list = avg_station.to_dict('records')
avg_station_list
# Out:
# [{'city': 'Mountain View',
#   'name': 'Castro Street and El Camino Real',
#   'yr': '2014',
#   'avg_trip': 31.0},
#  {'city': 'Mountain View',
#   'name': 'Castro Street and El Camino Real',
#   'yr': '2015',
#   'avg_trip': 32.0},
#  {'city': 'Mountain View',
#   'name': 'Evelyn Park and Ride',
#   'yr': '2013',
#   'avg_trip': 17.0},
#  {'city': 'Mountain View',
#   'name': 'Evelyn Park and Ride',
#   'yr': '2014',
#   'avg_trip': 20.0},
#  {'city': 'Mountain View',
#   'name': 'Evelyn Park and Ride',
#   'yr': '2015',
#   'avg_trip': 18.0},
#  {'city': 'Mountain View',
#   'name': 'Mountain View Caltrain Station',
#   'yr': '2013',
#   'avg_trip': 44.0},
#  {'city': 'Mountain View',
#   'name': 'Mountain View Caltrain Station',
#   'yr': '2014',
#   'avg_trip': 21.0},
#  {'city': 'Mountain View',
#   'name': 'Mountain View Caltrain Station',
#   'yr': '2015',
#   'avg_trip': 21.0},
#  {'city': 'Mountain View',
#   'name': 'Mountain View City Hall',
#   'yr': '2013',
#   'avg_trip': 20.0},
#  {'city': 'Mountain View',
#   'name': 'Mountain View City Hall',
#   'yr': '2014',
#   'avg_trip': 26.0},
#  {'city': 'Mountain View',
#   'name': 'Mountain View City Hall',
#   'yr': '2015',
#   'avg_trip': 18.0},
#  {'city': 'Mountain View',
#   'name': 'Rengstorff Avenue / California Street',
#   'yr': '2013',
#   'avg_trip': 134.0},
#  {'city': 'Mountain View',
#   'name': 'Rengstorff Avenue / California Street',
#   'yr': '2014',
#   'avg_trip': 73.0},
#  {'city': 'Mountain View',
#   'name': 'Rengstorff Avenue / California Street',
#   'yr': '2015',
#   'avg_trip': 31.0},
#  {'city': 'Mountain View',
#   'name': 'San Antonio Caltrain Station',
#   'yr': '2013',
#   'avg_trip': 44.0},
#  {'city': 'Mountain View',
#   'name': 'San Antonio Caltrain Station',
#   'yr': '2014',
#   'avg_trip': 47.0},
#  {'city': 'Mountain View',
#   'name': 'San Antonio Caltrain Station',
#   'yr': '2015',
#   'avg_trip': 26.0},
#  {'city': 'Mountain View',
#   'name': 'San Antonio Shopping Center',
#   'yr': '2014',
#   'avg_trip': 23.0},
#  {'city': 'Mountain View',
#   'name': 'San Antonio Shopping Center',
#   'yr': '2015',
#   'avg_trip': 60.0},
#  {'city': 'Palo Alto',
#   'name': 'California Ave Caltrain Station',
#   'yr': '2013',
#   'avg_trip': 94.0},
#  {'city': 'Palo Alto',
#   'name': 'California Ave Caltrain Station',
#   'yr': '2014',
#   'avg_trip': 72.0},
#  {'city': 'Palo Alto',
#   'name': 'California Ave Caltrain Station',
#   'yr': '2015',
#   'avg_trip': 74.0},
#  {'city': 'Palo Alto',
#   'name': 'Cowper at University',
#   'yr': '2013',
#   'avg_trip': 49.0},
#  {'city': 'Palo Alto',
#   'name': 'Cowper at University',
#   'yr': '2014',
#   'avg_trip': 37.0},
#  {'city': 'Palo Alto',
#   'name': 'Cowper at University',
#   'yr': '2015',
#   'avg_trip': 45.0},
#  {'city': 'Palo Alto',
#   'name': 'Palo Alto Caltrain Station',
#   'yr': '2013',
#   'avg_trip': 50.0},
#  {'city': 'Palo Alto',
#   'name': 'Palo Alto Caltrain Station',
#   'yr': '2014',
#   'avg_trip': 54.0},
#  {'city': 'Palo Alto',
#   'name': 'Palo Alto Caltrain Station',
#   'yr': '2015',
#   'avg_trip': 55.0},
#  {'city': 'Palo Alto',
#   'name': 'Park at Olive',
#   'yr': '2013',
#   'avg_trip': 80.0},
#  {'city': 'Palo Alto',
#   'name': 'Park at Olive',
#   'yr': '2014',
#   'avg_trip': 62.0},
#  {'city': 'Palo Alto',
#   'name': 'Park at Olive',
#   'yr': '2015',
#   'avg_trip': 86.0},
#  {'city': 'Palo Alto',
#   'name': 'University and Emerson',
#   'yr': '2013',
#   'avg_trip': 130.0},
#  {'city': 'Palo Alto',
#   'name': 'University and Emerson',
#   'yr': '2014',
#   'avg_trip': 91.0},
#  {'city': 'Palo Alto',
#   'name': 'University and Emerson',
#   'yr': '2015',
#   'avg_trip': 163.0},
#  {'city': 'Redwood City',
#   'name': 'Franklin at Maple',
#   'yr': '2013',
#   'avg_trip': 33.0},
#  {'city': 'Redwood City',
#   'name': 'Franklin at Maple',
#   'yr': '2014',
#   'avg_trip': 13.0},
#  {'city': 'Redwood City',
#   'name': 'Franklin at Maple',
#   'yr': '2015',
#   'avg_trip': 46.0},
#  {'city': 'Redwood City',
#   'name': 'Mezes Park',
#   'yr': '2014',
#   'avg_trip': 13.0},
#  {'city': 'Redwood City',
#   'name': 'Mezes Park',
#   'yr': '2015',
#   'avg_trip': 42.0},
#  {'city': 'Redwood City',
#   'name': 'Redwood City Caltrain Station',
#   'yr': '2013',
#   'avg_trip': 28.0},
#  {'city': 'Redwood City',
#   'name': 'Redwood City Caltrain Station',
#   'yr': '2014',
#   'avg_trip': 70.0},
#  {'city': 'Redwood City',
#   'name': 'Redwood City Caltrain Station',
#   'yr': '2015',
#   'avg_trip': 24.0},
#  {'city': 'Redwood City',
#   'name': 'Redwood City Medical Center',
#   'yr': '2013',
#   'avg_trip': 43.0},
#  {'city': 'Redwood City',
#   'name': 'Redwood City Medical Center',
#   'yr': '2014',
#   'avg_trip': 32.0},
#  {'city': 'Redwood City',
#   'name': 'Redwood City Medical Center',
#   'yr': '2015',
#   'avg_trip': 104.0},
#  {'city': 'Redwood City',
#   'name': 'Redwood City Public Library',
#   'yr': '2013',
#   'avg_trip': 173.0},
#  {'city': 'Redwood City',
#   'name': 'Redwood City Public Library',
#   'yr': '2014',
#   'avg_trip': 58.0},
#  {'city': 'Redwood City',
#   'name': 'Redwood City Public Library',
#   'yr': '2015',
#   'avg_trip': 53.0},
#  {'city': 'Redwood City',
#   'name': 'San Mateo County Center',
#   'yr': '2013',
#   'avg_trip': 24.0},
#  {'city': 'Redwood City',
#   'name': 'San Mateo County Center',
#   'yr': '2014',
#   'avg_trip': 67.0},
#  {'city': 'Redwood City',
#   'name': 'San Mateo County Center',
#   'yr': '2015',
#   'avg_trip': 39.0},
#  {'city': 'Redwood City',
#   'name': 'Stanford in Redwood City',
#   'yr': '2013',
#   'avg_trip': 20.0},
#  {'city': 'Redwood City',
#   'name': 'Stanford in Redwood City',
#   'yr': '2014',
#   'avg_trip': 43.0},
#  {'city': 'Redwood City',
#   'name': 'Stanford in Redwood City',
#   'yr': '2015',
#   'avg_trip': 18.0},
#  {'city': 'San Francisco',
#   'name': '2nd at Folsom',
#   'yr': '2013',
#   'avg_trip': 13.0},
#  {'city': 'San Francisco',
#   'name': '2nd at Folsom',
#   'yr': '2014',
#   'avg_trip': 9.0},
#  {'city': 'San Francisco',
#   'name': '2nd at Folsom',
#   'yr': '2015',
#   'avg_trip': 9.0},
#  {'city': 'San Francisco',
#   'name': '2nd at South Park',
#   'yr': '2013',
#   'avg_trip': 12.0},
#  {'city': 'San Francisco',
#   'name': '2nd at South Park',
#   'yr': '2014',
#   'avg_trip': 12.0},
#  {'city': 'San Francisco',
#   'name': '2nd at South Park',
#   'yr': '2015',
#   'avg_trip': 11.0},
#  {'city': 'San Francisco',
#   'name': '2nd at Townsend',
#   'yr': '2013',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': '2nd at Townsend',
#   'yr': '2014',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': '2nd at Townsend',
#   'yr': '2015',
#   'avg_trip': 12.0},
#  {'city': 'San Francisco',
#   'name': '5th at Howard',
#   'yr': '2013',
#   'avg_trip': 23.0},
#  {'city': 'San Francisco',
#   'name': '5th at Howard',
#   'yr': '2014',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': '5th at Howard',
#   'yr': '2015',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': 'Beale at Market',
#   'yr': '2013',
#   'avg_trip': 21.0},
#  {'city': 'San Francisco',
#   'name': 'Beale at Market',
#   'yr': '2014',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': 'Beale at Market',
#   'yr': '2015',
#   'avg_trip': 12.0},
#  {'city': 'San Francisco',
#   'name': 'Broadway St at Battery St',
#   'yr': '2014',
#   'avg_trip': 15.0},
#  {'city': 'San Francisco',
#   'name': 'Broadway St at Battery St',
#   'yr': '2015',
#   'avg_trip': 13.0},
#  {'city': 'San Francisco',
#   'name': 'Civic Center BART (7th at Market)',
#   'yr': '2013',
#   'avg_trip': 26.0},
#  {'city': 'San Francisco',
#   'name': 'Civic Center BART (7th at Market)',
#   'yr': '2014',
#   'avg_trip': 21.0},
#  {'city': 'San Francisco',
#   'name': 'Civic Center BART (7th at Market)',
#   'yr': '2015',
#   'avg_trip': 16.0},
#  {'city': 'San Francisco',
#   'name': 'Clay at Battery',
#   'yr': '2013',
#   'avg_trip': 19.0},
#  {'city': 'San Francisco',
#   'name': 'Clay at Battery',
#   'yr': '2014',
#   'avg_trip': 20.0},
#  {'city': 'San Francisco',
#   'name': 'Clay at Battery',
#   'yr': '2015',
#   'avg_trip': 15.0},
#  {'city': 'San Francisco',
#   'name': 'Commercial at Montgomery',
#   'yr': '2013',
#   'avg_trip': 13.0},
#  {'city': 'San Francisco',
#   'name': 'Commercial at Montgomery',
#   'yr': '2014',
#   'avg_trip': 13.0},
#  {'city': 'San Francisco',
#   'name': 'Commercial at Montgomery',
#   'yr': '2015',
#   'avg_trip': 13.0},
#  {'city': 'San Francisco',
#   'name': 'Davis at Jackson',
#   'yr': '2013',
#   'avg_trip': 21.0},
#  {'city': 'San Francisco',
#   'name': 'Davis at Jackson',
#   'yr': '2014',
#   'avg_trip': 16.0},
#  {'city': 'San Francisco',
#   'name': 'Davis at Jackson',
#   'yr': '2015',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': 'Embarcadero at Bryant',
#   'yr': '2013',
#   'avg_trip': 22.0},
#  {'city': 'San Francisco',
#   'name': 'Embarcadero at Bryant',
#   'yr': '2014',
#   'avg_trip': 17.0},
#  {'city': 'San Francisco',
#   'name': 'Embarcadero at Bryant',
#   'yr': '2015',
#   'avg_trip': 15.0},
#  {'city': 'San Francisco',
#   'name': 'Embarcadero at Folsom',
#   'yr': '2013',
#   'avg_trip': 15.0},
#  {'city': 'San Francisco',
#   'name': 'Embarcadero at Folsom',
#   'yr': '2014',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': 'Embarcadero at Folsom',
#   'yr': '2015',
#   'avg_trip': 13.0},
#  {'city': 'San Francisco',
#   'name': 'Embarcadero at Sansome',
#   'yr': '2013',
#   'avg_trip': 28.0},
#  {'city': 'San Francisco',
#   'name': 'Embarcadero at Sansome',
#   'yr': '2014',
#   'avg_trip': 24.0},
#  {'city': 'San Francisco',
#   'name': 'Embarcadero at Sansome',
#   'yr': '2015',
#   'avg_trip': 21.0},
#  {'city': 'San Francisco',
#   'name': 'Embarcadero at Vallejo',
#   'yr': '2013',
#   'avg_trip': 27.0},
#  {'city': 'San Francisco',
#   'name': 'Embarcadero at Vallejo',
#   'yr': '2014',
#   'avg_trip': 27.0},
#  {'city': 'San Francisco',
#   'name': 'Embarcadero at Vallejo',
#   'yr': '2015',
#   'avg_trip': 27.0},
#  {'city': 'San Francisco',
#   'name': 'Golden Gate at Polk',
#   'yr': '2013',
#   'avg_trip': 19.0},
#  {'city': 'San Francisco',
#   'name': 'Golden Gate at Polk',
#   'yr': '2014',
#   'avg_trip': 20.0},
#  {'city': 'San Francisco',
#   'name': 'Golden Gate at Polk',
#   'yr': '2015',
#   'avg_trip': 18.0},
#  {'city': 'San Francisco',
#   'name': 'Grant Avenue at Columbus Avenue',
#   'yr': '2013',
#   'avg_trip': 22.0},
#  {'city': 'San Francisco',
#   'name': 'Grant Avenue at Columbus Avenue',
#   'yr': '2014',
#   'avg_trip': 21.0},
#  {'city': 'San Francisco',
#   'name': 'Grant Avenue at Columbus Avenue',
#   'yr': '2015',
#   'avg_trip': 18.0},
#  {'city': 'San Francisco',
#   'name': 'Harry Bridges Plaza (Ferry Building)',
#   'yr': '2013',
#   'avg_trip': 31.0},
#  {'city': 'San Francisco',
#   'name': 'Harry Bridges Plaza (Ferry Building)',
#   'yr': '2014',
#   'avg_trip': 25.0},
#  {'city': 'San Francisco',
#   'name': 'Harry Bridges Plaza (Ferry Building)',
#   'yr': '2015',
#   'avg_trip': 22.0},
#  {'city': 'San Francisco',
#   'name': 'Howard at 2nd',
#   'yr': '2013',
#   'avg_trip': 15.0},
#  {'city': 'San Francisco',
#   'name': 'Howard at 2nd',
#   'yr': '2014',
#   'avg_trip': 12.0},
#  {'city': 'San Francisco',
#   'name': 'Howard at 2nd',
#   'yr': '2015',
#   'avg_trip': 12.0},
#  {'city': 'San Francisco',
#   'name': 'Market at 10th',
#   'yr': '2013',
#   'avg_trip': 21.0},
#  {'city': 'San Francisco',
#   'name': 'Market at 10th',
#   'yr': '2014',
#   'avg_trip': 18.0},
#  {'city': 'San Francisco',
#   'name': 'Market at 10th',
#   'yr': '2015',
#   'avg_trip': 16.0},
#  {'city': 'San Francisco',
#   'name': 'Market at 4th',
#   'yr': '2013',
#   'avg_trip': 28.0},
#  {'city': 'San Francisco',
#   'name': 'Market at 4th',
#   'yr': '2014',
#   'avg_trip': 21.0},
#  {'city': 'San Francisco',
#   'name': 'Market at 4th',
#   'yr': '2015',
#   'avg_trip': 19.0},
#  {'city': 'San Francisco',
#   'name': 'Market at Sansome',
#   'yr': '2013',
#   'avg_trip': 18.0},
#  {'city': 'San Francisco',
#   'name': 'Market at Sansome',
#   'yr': '2014',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': 'Market at Sansome',
#   'yr': '2015',
#   'avg_trip': 17.0},
#  {'city': 'San Francisco',
#   'name': 'Mechanics Plaza (Market at Battery)',
#   'yr': '2013',
#   'avg_trip': 20.0},
#  {'city': 'San Francisco',
#   'name': 'Mechanics Plaza (Market at Battery)',
#   'yr': '2014',
#   'avg_trip': 17.0},
#  {'city': 'San Francisco',
#   'name': 'Mechanics Plaza (Market at Battery)',
#   'yr': '2015',
#   'avg_trip': 16.0},
#  {'city': 'San Francisco',
#   'name': 'Post at Kearney',
#   'yr': '2013',
#   'avg_trip': 18.0},
#  {'city': 'San Francisco',
#   'name': 'Post at Kearney',
#   'yr': '2014',
#   'avg_trip': 17.0},
#  {'city': 'San Francisco',
#   'name': 'Post at Kearney',
#   'yr': '2015',
#   'avg_trip': 15.0},
#  {'city': 'San Francisco',
#   'name': 'Powell Street BART',
#   'yr': '2013',
#   'avg_trip': 29.0},
#  {'city': 'San Francisco',
#   'name': 'Powell Street BART',
#   'yr': '2014',
#   'avg_trip': 22.0},
#  {'city': 'San Francisco',
#   'name': 'Powell Street BART',
#   'yr': '2015',
#   'avg_trip': 22.0},
#  {'city': 'San Francisco',
#   'name': 'Powell at Post (Union Square)',
#   'yr': '2013',
#   'avg_trip': 40.0},
#  {'city': 'San Francisco',
#   'name': 'Powell at Post (Union Square)',
#   'yr': '2014',
#   'avg_trip': 27.0},
#  {'city': 'San Francisco',
#   'name': 'Powell at Post (Union Square)',
#   'yr': '2015',
#   'avg_trip': 20.0},
#  {'city': 'San Francisco',
#   'name': 'San Francisco Caltrain (Townsend at 4th)',
#   'yr': '2013',
#   'avg_trip': 15.0},
#  {'city': 'San Francisco',
#   'name': 'San Francisco Caltrain (Townsend at 4th)',
#   'yr': '2014',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': 'San Francisco Caltrain (Townsend at 4th)',
#   'yr': '2015',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': 'San Francisco Caltrain 2 (330 Townsend)',
#   'yr': '2013',
#   'avg_trip': 13.0},
#  {'city': 'San Francisco',
#   'name': 'San Francisco Caltrain 2 (330 Townsend)',
#   'yr': '2014',
#   'avg_trip': 12.0},
#  {'city': 'San Francisco',
#   'name': 'San Francisco Caltrain 2 (330 Townsend)',
#   'yr': '2015',
#   'avg_trip': 11.0},
#  {'city': 'San Francisco',
#   'name': 'San Francisco City Hall',
#   'yr': '2013',
#   'avg_trip': 27.0},
#  {'city': 'San Francisco',
#   'name': 'San Francisco City Hall',
#   'yr': '2014',
#   'avg_trip': 32.0},
#  {'city': 'San Francisco',
#   'name': 'San Francisco City Hall',
#   'yr': '2015',
#   'avg_trip': 27.0},
#  {'city': 'San Francisco',
#   'name': 'South Van Ness at Market',
#   'yr': '2013',
#   'avg_trip': 20.0},
#  {'city': 'San Francisco',
#   'name': 'South Van Ness at Market',
#   'yr': '2014',
#   'avg_trip': 63.0},
#  {'city': 'San Francisco',
#   'name': 'South Van Ness at Market',
#   'yr': '2015',
#   'avg_trip': 15.0},
#  {'city': 'San Francisco',
#   'name': 'Spear at Folsom',
#   'yr': '2013',
#   'avg_trip': 13.0},
#  {'city': 'San Francisco',
#   'name': 'Spear at Folsom',
#   'yr': '2014',
#   'avg_trip': 12.0},
#  {'city': 'San Francisco',
#   'name': 'Spear at Folsom',
#   'yr': '2015',
#   'avg_trip': 15.0},
#  {'city': 'San Francisco',
#   'name': 'Steuart at Market',
#   'yr': '2013',
#   'avg_trip': 19.0},
#  {'city': 'San Francisco',
#   'name': 'Steuart at Market',
#   'yr': '2014',
#   'avg_trip': 16.0},
#  {'city': 'San Francisco',
#   'name': 'Steuart at Market',
#   'yr': '2015',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': 'Temporary Transbay Terminal (Howard at Beale)',
#   'yr': '2013',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': 'Temporary Transbay Terminal (Howard at Beale)',
#   'yr': '2014',
#   'avg_trip': 11.0},
#  {'city': 'San Francisco',
#   'name': 'Temporary Transbay Terminal (Howard at Beale)',
#   'yr': '2015',
#   'avg_trip': 10.0},
#  {'city': 'San Francisco',
#   'name': 'Townsend at 7th',
#   'yr': '2013',
#   'avg_trip': 14.0},
#  {'city': 'San Francisco',
#   'name': 'Townsend at 7th',
#   'yr': '2014',
#   'avg_trip': 12.0},
#  {'city': 'San Francisco',
#   'name': 'Townsend at 7th',
#   'yr': '2015',
#   'avg_trip': 10.0},
#  {'city': 'San Francisco',
#   'name': 'Washington at Kearney',
#   'yr': '2013',
#   'avg_trip': 31.0},
#  {'city': 'San Francisco',
#   'name': 'Washington at Kearney',
#   'yr': '2014',
#   'avg_trip': 32.0},
#  {'city': 'San Francisco',
#   'name': 'Washington at Kearney',
#   'yr': '2015',
#   'avg_trip': 22.0},
#  {'city': 'San Francisco',
#   'name': 'Yerba Buena Center of the Arts (3rd @ Howard)',
#   'yr': '2013',
#   'avg_trip': 22.0},
#  {'city': 'San Francisco',
#   'name': 'Yerba Buena Center of the Arts (3rd @ Howard)',
#   'yr': '2014',
#   'avg_trip': 15.0},
#  {'city': 'San Francisco',
#   'name': 'Yerba Buena Center of the Arts (3rd @ Howard)',
#   'yr': '2015',
#   'avg_trip': 14.0},
#  {'city': 'San Jose',
#   'name': 'Adobe on Almaden',
#   'yr': '2013',
#   'avg_trip': 20.0},
#  {'city': 'San Jose',
#   'name': 'Adobe on Almaden',
#   'yr': '2014',
#   'avg_trip': 14.0},
#  {'city': 'San Jose',
#   'name': 'Adobe on Almaden',
#   'yr': '2015',
#   'avg_trip': 30.0},
#  {'city': 'San Jose',
#   'name': 'Arena Green / SAP Center',
#   'yr': '2013',
#   'avg_trip': 33.0},
#  {'city': 'San Jose',
#   'name': 'Arena Green / SAP Center',
#   'yr': '2014',
#   'avg_trip': 34.0},
#  {'city': 'San Jose',
#   'name': 'Arena Green / SAP Center',
#   'yr': '2015',
#   'avg_trip': 30.0},
#  {'city': 'San Jose', 'name': 'Japantown', 'yr': '2013', 'avg_trip': 37.0},
#  {'city': 'San Jose', 'name': 'Japantown', 'yr': '2014', 'avg_trip': 41.0},
#  {'city': 'San Jose', 'name': 'Japantown', 'yr': '2015', 'avg_trip': 31.0},
#  {'city': 'San Jose', 'name': 'MLK Library', 'yr': '2013', 'avg_trip': 26.0},
#  {'city': 'San Jose', 'name': 'MLK Library', 'yr': '2014', 'avg_trip': 31.0},
#  {'city': 'San Jose', 'name': 'MLK Library', 'yr': '2015', 'avg_trip': 18.0},
#  {'city': 'San Jose',
#   'name': 'Paseo de San Antonio',
#   'yr': '2013',
#   'avg_trip': 13.0},
#  {'city': 'San Jose',
#   'name': 'Paseo de San Antonio',
#   'yr': '2014',
#   'avg_trip': 30.0},
#  {'city': 'San Jose',
#   'name': 'Paseo de San Antonio',
#   'yr': '2015',
#   'avg_trip': 16.0},
#  {'city': 'San Jose', 'name': 'Ryland Park', 'yr': '2014', 'avg_trip': 23.0},
#  {'city': 'San Jose', 'name': 'Ryland Park', 'yr': '2015', 'avg_trip': 12.0},
#  {'city': 'San Jose',
#   'name': 'SJSU - San Salvador at 9th',
#   'yr': '2013',
#   'avg_trip': 34.0},
#  {'city': 'San Jose',
#   'name': 'SJSU - San Salvador at 9th',
#   'yr': '2014',
#   'avg_trip': 16.0},
#  {'city': 'San Jose',
#   'name': 'SJSU - San Salvador at 9th',
#   'yr': '2015',
#   'avg_trip': 25.0},
#  {'city': 'San Jose',
#   'name': 'SJSU 4th at San Carlos',
#   'yr': '2013',
#   'avg_trip': 52.0},
#  {'city': 'San Jose',
#   'name': 'SJSU 4th at San Carlos',
#   'yr': '2014',
#   'avg_trip': 35.0},
#  {'city': 'San Jose',
#   'name': 'SJSU 4th at San Carlos',
#   'yr': '2015',
#   'avg_trip': 14.0},
#  {'city': 'San Jose',
#   'name': 'San Jose City Hall',
#   'yr': '2013',
#   'avg_trip': 31.0},
#  {'city': 'San Jose',
#   'name': 'San Jose City Hall',
#   'yr': '2014',
#   'avg_trip': 17.0},
#  {'city': 'San Jose',
#   'name': 'San Jose City Hall',
#   'yr': '2015',
#   'avg_trip': 16.0},
#  {'city': 'San Jose',
#   'name': 'San Jose Civic Center',
#   'yr': '2013',
#   'avg_trip': 62.0},
#  {'city': 'San Jose',
#   'name': 'San Jose Civic Center',
#   'yr': '2014',
#   'avg_trip': 59.0},
#  {'city': 'San Jose',
#   'name': 'San Jose Civic Center',
#   'yr': '2015',
#   'avg_trip': 92.0},
#  {'city': 'San Jose',
#   'name': 'San Jose Diridon Caltrain Station',
#   'yr': '2013',
#   'avg_trip': 20.0},
#  {'city': 'San Jose',
#   'name': 'San Jose Diridon Caltrain Station',
#   'yr': '2014',
#   'avg_trip': 14.0},
#  {'city': 'San Jose',
#   'name': 'San Jose Diridon Caltrain Station',
#   'yr': '2015',
#   'avg_trip': 15.0},
#  {'city': 'San Jose',
#   'name': 'San Pedro Square',
#   'yr': '2013',
#   'avg_trip': 23.0},
#  {'city': 'San Jose',
#   'name': 'San Pedro Square',
#   'yr': '2014',
#   'avg_trip': 16.0},
#  {'city': 'San Jose',
#   'name': 'San Pedro Square',
#   'yr': '2015',
#   'avg_trip': 35.0},
#  {'city': 'San Jose',
#   'name': 'San Salvador at 1st',
#   'yr': '2013',
#   'avg_trip': 16.0},
#  {'city': 'San Jose',
#   'name': 'San Salvador at 1st',
#   'yr': '2014',
#   'avg_trip': 18.0},
#  {'city': 'San Jose',
#   'name': 'San Salvador at 1st',
#   'yr': '2015',
#   'avg_trip': 38.0},
#  {'city': 'San Jose',
#   'name': 'Santa Clara County Civic Center',
#   'yr': '2014',
#   'avg_trip': 23.0},
#  {'city': 'San Jose',
#   'name': 'Santa Clara County Civic Center',
#   'yr': '2015',
#   'avg_trip': 28.0},
#  {'city': 'San Jose',
#   'name': 'Santa Clara at Almaden',
#   'yr': '2013',
#   'avg_trip': 17.0},
#  {'city': 'San Jose',
#   'name': 'Santa Clara at Almaden',
#   'yr': '2014',
#   'avg_trip': 16.0},
#  {'city': 'San Jose',
#   'name': 'Santa Clara at Almaden',
#   'yr': '2015',
#   'avg_trip': 16.0},
#  {'city': 'San Jose', 'name': 'St James Park', 'yr': '2013', 'avg_trip': 13.0},
#  {'city': 'San Jose', 'name': 'St James Park', 'yr': '2014', 'avg_trip': 16.0},
#  {'city': 'San Jose', 'name': 'St James Park', 'yr': '2015', 'avg_trip': 16.0}]

# %%
yrs_2013 = []
yrs_2014 = []
yrs_2015 = []

for item in avg_station_list:
    for k,v in item.items():
        print(k)
# Out:
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip
# city
# name
# yr
# avg_trip

# %%
yrs_2013 = []
yrs_2014 = []
yrs_2015 = []

for item in avg_station_list:
    data = {}
    for k,v in item.items():
        if(k=='name'):
            data['axis'] = v
        if(k=='avg_trip'):
            data['value'] = v
        if(k=='city'):
            data['city'] = v
        if(k=='yr'and v=='2013'):
            data['name'] = v
            yrs_2013.append(data)
        elif(k=='yr'and v=='2014'):
            data['name'] = v
            yrs_2014.append(data)
        elif(k=='yr'and v=='2015'):
            data['name'] = v
            yrs_2015.append(data)
    
all_yr_station = [yrs_2013, yrs_2014, yrs_2015]

# %%
all_yr_station
# Out:
# [[{'city': 'Mountain View',
#    'axis': 'Evelyn Park and Ride',
#    'name': '2013',
#    'value': 17.0},
#   {'city': 'Mountain View',
#    'axis': 'Mountain View Caltrain Station',
#    'name': '2013',
#    'value': 44.0},
#   {'city': 'Mountain View',
#    'axis': 'Mountain View City Hall',
#    'name': '2013',
#    'value': 20.0},
#   {'city': 'Mountain View',
#    'axis': 'Rengstorff Avenue / California Street',
#    'name': '2013',
#    'value': 134.0},
#   {'city': 'Mountain View',
#    'axis': 'San Antonio Caltrain Station',
#    'name': '2013',
#    'value': 44.0},
#   {'city': 'Palo Alto',
#    'axis': 'California Ave Caltrain Station',
#    'name': '2013',
#    'value': 94.0},
#   {'city': 'Palo Alto',
#    'axis': 'Cowper at University',
#    'name': '2013',
#    'value': 49.0},
#   {'city': 'Palo Alto',
#    'axis': 'Palo Alto Caltrain Station',
#    'name': '2013',
#    'value': 50.0},
#   {'city': 'Palo Alto',
#    'axis': 'Park at Olive',
#    'name': '2013',
#    'value': 80.0},
#   {'city': 'Palo Alto',
#    'axis': 'University and Emerson',
#    'name': '2013',
#    'value': 130.0},
#   {'city': 'Redwood City',
#    'axis': 'Franklin at Maple',
#    'name': '2013',
#    'value': 33.0},
#   {'city': 'Redwood City',
#    'axis': 'Redwood City Caltrain Station',
#    'name': '2013',
#    'value': 28.0},
#   {'city': 'Redwood City',
#    'axis': 'Redwood City Medical Center',
#    'name': '2013',
#    'value': 43.0},
#   {'city': 'Redwood City',
#    'axis': 'Redwood City Public Library',
#    'name': '2013',
#    'value': 173.0},
#   {'city': 'Redwood City',
#    'axis': 'San Mateo County Center',
#    'name': '2013',
#    'value': 24.0},
#   {'city': 'Redwood City',
#    'axis': 'Stanford in Redwood City',
#    'name': '2013',
#    'value': 20.0},
#   {'city': 'San Francisco',
#    'axis': '2nd at Folsom',
#    'name': '2013',
#    'value': 13.0},
#   {'city': 'San Francisco',
#    'axis': '2nd at South Park',
#    'name': '2013',
#    'value': 12.0},
#   {'city': 'San Francisco',
#    'axis': '2nd at Townsend',
#    'name': '2013',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': '5th at Howard',
#    'name': '2013',
#    'value': 23.0},
#   {'city': 'San Francisco',
#    'axis': 'Beale at Market',
#    'name': '2013',
#    'value': 21.0},
#   {'city': 'San Francisco',
#    'axis': 'Civic Center BART (7th at Market)',
#    'name': '2013',
#    'value': 26.0},
#   {'city': 'San Francisco',
#    'axis': 'Clay at Battery',
#    'name': '2013',
#    'value': 19.0},
#   {'city': 'San Francisco',
#    'axis': 'Commercial at Montgomery',
#    'name': '2013',
#    'value': 13.0},
#   {'city': 'San Francisco',
#    'axis': 'Davis at Jackson',
#    'name': '2013',
#    'value': 21.0},
#   {'city': 'San Francisco',
#    'axis': 'Embarcadero at Bryant',
#    'name': '2013',
#    'value': 22.0},
#   {'city': 'San Francisco',
#    'axis': 'Embarcadero at Folsom',
#    'name': '2013',
#    'value': 15.0},
#   {'city': 'San Francisco',
#    'axis': 'Embarcadero at Sansome',
#    'name': '2013',
#    'value': 28.0},
#   {'city': 'San Francisco',
#    'axis': 'Embarcadero at Vallejo',
#    'name': '2013',
#    'value': 27.0},
#   {'city': 'San Francisco',
#    'axis': 'Golden Gate at Polk',
#    'name': '2013',
#    'value': 19.0},
#   {'city': 'San Francisco',
#    'axis': 'Grant Avenue at Columbus Avenue',
#    'name': '2013',
#    'value': 22.0},
#   {'city': 'San Francisco',
#    'axis': 'Harry Bridges Plaza (Ferry Building)',
#    'name': '2013',
#    'value': 31.0},
#   {'city': 'San Francisco',
#    'axis': 'Howard at 2nd',
#    'name': '2013',
#    'value': 15.0},
#   {'city': 'San Francisco',
#    'axis': 'Market at 10th',
#    'name': '2013',
#    'value': 21.0},
#   {'city': 'San Francisco',
#    'axis': 'Market at 4th',
#    'name': '2013',
#    'value': 28.0},
#   {'city': 'San Francisco',
#    'axis': 'Market at Sansome',
#    'name': '2013',
#    'value': 18.0},
#   {'city': 'San Francisco',
#    'axis': 'Mechanics Plaza (Market at Battery)',
#    'name': '2013',
#    'value': 20.0},
#   {'city': 'San Francisco',
#    'axis': 'Post at Kearney',
#    'name': '2013',
#    'value': 18.0},
#   {'city': 'San Francisco',
#    'axis': 'Powell Street BART',
#    'name': '2013',
#    'value': 29.0},
#   {'city': 'San Francisco',
#    'axis': 'Powell at Post (Union Square)',
#    'name': '2013',
#    'value': 40.0},
#   {'city': 'San Francisco',
#    'axis': 'San Francisco Caltrain (Townsend at 4th)',
#    'name': '2013',
#    'value': 15.0},
#   {'city': 'San Francisco',
#    'axis': 'San Francisco Caltrain 2 (330 Townsend)',
#    'name': '2013',
#    'value': 13.0},
#   {'city': 'San Francisco',
#    'axis': 'San Francisco City Hall',
#    'name': '2013',
#    'value': 27.0},
#   {'city': 'San Francisco',
#    'axis': 'South Van Ness at Market',
#    'name': '2013',
#    'value': 20.0},
#   {'city': 'San Francisco',
#    'axis': 'Spear at Folsom',
#    'name': '2013',
#    'value': 13.0},
#   {'city': 'San Francisco',
#    'axis': 'Steuart at Market',
#    'name': '2013',
#    'value': 19.0},
#   {'city': 'San Francisco',
#    'axis': 'Temporary Transbay Terminal (Howard at Beale)',
#    'name': '2013',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': 'Townsend at 7th',
#    'name': '2013',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': 'Washington at Kearney',
#    'name': '2013',
#    'value': 31.0},
#   {'city': 'San Francisco',
#    'axis': 'Yerba Buena Center of the Arts (3rd @ Howard)',
#    'name': '2013',
#    'value': 22.0},
#   {'city': 'San Jose',
#    'axis': 'Adobe on Almaden',
#    'name': '2013',
#    'value': 20.0},
#   {'city': 'San Jose',
#    'axis': 'Arena Green / SAP Center',
#    'name': '2013',
#    'value': 33.0},
#   {'city': 'San Jose', 'axis': 'Japantown', 'name': '2013', 'value': 37.0},
#   {'city': 'San Jose', 'axis': 'MLK Library', 'name': '2013', 'value': 26.0},
#   {'city': 'San Jose',
#    'axis': 'Paseo de San Antonio',
#    'name': '2013',
#    'value': 13.0},
#   {'city': 'San Jose',
#    'axis': 'SJSU - San Salvador at 9th',
#    'name': '2013',
#    'value': 34.0},
#   {'city': 'San Jose',
#    'axis': 'SJSU 4th at San Carlos',
#    'name': '2013',
#    'value': 52.0},
#   {'city': 'San Jose',
#    'axis': 'San Jose City Hall',
#    'name': '2013',
#    'value': 31.0},
#   {'city': 'San Jose',
#    'axis': 'San Jose Civic Center',
#    'name': '2013',
#    'value': 62.0},
#   {'city': 'San Jose',
#    'axis': 'San Jose Diridon Caltrain Station',
#    'name': '2013',
#    'value': 20.0},
#   {'city': 'San Jose',
#    'axis': 'San Pedro Square',
#    'name': '2013',
#    'value': 23.0},
#   {'city': 'San Jose',
#    'axis': 'San Salvador at 1st',
#    'name': '2013',
#    'value': 16.0},
#   {'city': 'San Jose',
#    'axis': 'Santa Clara at Almaden',
#    'name': '2013',
#    'value': 17.0},
#   {'city': 'San Jose',
#    'axis': 'St James Park',
#    'name': '2013',
#    'value': 13.0}],
#  [{'city': 'Mountain View',
#    'axis': 'Castro Street and El Camino Real',
#    'name': '2014',
#    'value': 31.0},
#   {'city': 'Mountain View',
#    'axis': 'Evelyn Park and Ride',
#    'name': '2014',
#    'value': 20.0},
#   {'city': 'Mountain View',
#    'axis': 'Mountain View Caltrain Station',
#    'name': '2014',
#    'value': 21.0},
#   {'city': 'Mountain View',
#    'axis': 'Mountain View City Hall',
#    'name': '2014',
#    'value': 26.0},
#   {'city': 'Mountain View',
#    'axis': 'Rengstorff Avenue / California Street',
#    'name': '2014',
#    'value': 73.0},
#   {'city': 'Mountain View',
#    'axis': 'San Antonio Caltrain Station',
#    'name': '2014',
#    'value': 47.0},
#   {'city': 'Mountain View',
#    'axis': 'San Antonio Shopping Center',
#    'name': '2014',
#    'value': 23.0},
#   {'city': 'Palo Alto',
#    'axis': 'California Ave Caltrain Station',
#    'name': '2014',
#    'value': 72.0},
#   {'city': 'Palo Alto',
#    'axis': 'Cowper at University',
#    'name': '2014',
#    'value': 37.0},
#   {'city': 'Palo Alto',
#    'axis': 'Palo Alto Caltrain Station',
#    'name': '2014',
#    'value': 54.0},
#   {'city': 'Palo Alto',
#    'axis': 'Park at Olive',
#    'name': '2014',
#    'value': 62.0},
#   {'city': 'Palo Alto',
#    'axis': 'University and Emerson',
#    'name': '2014',
#    'value': 91.0},
#   {'city': 'Redwood City',
#    'axis': 'Franklin at Maple',
#    'name': '2014',
#    'value': 13.0},
#   {'city': 'Redwood City',
#    'axis': 'Mezes Park',
#    'name': '2014',
#    'value': 13.0},
#   {'city': 'Redwood City',
#    'axis': 'Redwood City Caltrain Station',
#    'name': '2014',
#    'value': 70.0},
#   {'city': 'Redwood City',
#    'axis': 'Redwood City Medical Center',
#    'name': '2014',
#    'value': 32.0},
#   {'city': 'Redwood City',
#    'axis': 'Redwood City Public Library',
#    'name': '2014',
#    'value': 58.0},
#   {'city': 'Redwood City',
#    'axis': 'San Mateo County Center',
#    'name': '2014',
#    'value': 67.0},
#   {'city': 'Redwood City',
#    'axis': 'Stanford in Redwood City',
#    'name': '2014',
#    'value': 43.0},
#   {'city': 'San Francisco',
#    'axis': '2nd at Folsom',
#    'name': '2014',
#    'value': 9.0},
#   {'city': 'San Francisco',
#    'axis': '2nd at South Park',
#    'name': '2014',
#    'value': 12.0},
#   {'city': 'San Francisco',
#    'axis': '2nd at Townsend',
#    'name': '2014',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': '5th at Howard',
#    'name': '2014',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': 'Beale at Market',
#    'name': '2014',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': 'Broadway St at Battery St',
#    'name': '2014',
#    'value': 15.0},
#   {'city': 'San Francisco',
#    'axis': 'Civic Center BART (7th at Market)',
#    'name': '2014',
#    'value': 21.0},
#   {'city': 'San Francisco',
#    'axis': 'Clay at Battery',
#    'name': '2014',
#    'value': 20.0},
#   {'city': 'San Francisco',
#    'axis': 'Commercial at Montgomery',
#    'name': '2014',
#    'value': 13.0},
#   {'city': 'San Francisco',
#    'axis': 'Davis at Jackson',
#    'name': '2014',
#    'value': 16.0},
#   {'city': 'San Francisco',
#    'axis': 'Embarcadero at Bryant',
#    'name': '2014',
#    'value': 17.0},
#   {'city': 'San Francisco',
#    'axis': 'Embarcadero at Folsom',
#    'name': '2014',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': 'Embarcadero at Sansome',
#    'name': '2014',
#    'value': 24.0},
#   {'city': 'San Francisco',
#    'axis': 'Embarcadero at Vallejo',
#    'name': '2014',
#    'value': 27.0},
#   {'city': 'San Francisco',
#    'axis': 'Golden Gate at Polk',
#    'name': '2014',
#    'value': 20.0},
#   {'city': 'San Francisco',
#    'axis': 'Grant Avenue at Columbus Avenue',
#    'name': '2014',
#    'value': 21.0},
#   {'city': 'San Francisco',
#    'axis': 'Harry Bridges Plaza (Ferry Building)',
#    'name': '2014',
#    'value': 25.0},
#   {'city': 'San Francisco',
#    'axis': 'Howard at 2nd',
#    'name': '2014',
#    'value': 12.0},
#   {'city': 'San Francisco',
#    'axis': 'Market at 10th',
#    'name': '2014',
#    'value': 18.0},
#   {'city': 'San Francisco',
#    'axis': 'Market at 4th',
#    'name': '2014',
#    'value': 21.0},
#   {'city': 'San Francisco',
#    'axis': 'Market at Sansome',
#    'name': '2014',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': 'Mechanics Plaza (Market at Battery)',
#    'name': '2014',
#    'value': 17.0},
#   {'city': 'San Francisco',
#    'axis': 'Post at Kearney',
#    'name': '2014',
#    'value': 17.0},
#   {'city': 'San Francisco',
#    'axis': 'Powell Street BART',
#    'name': '2014',
#    'value': 22.0},
#   {'city': 'San Francisco',
#    'axis': 'Powell at Post (Union Square)',
#    'name': '2014',
#    'value': 27.0},
#   {'city': 'San Francisco',
#    'axis': 'San Francisco Caltrain (Townsend at 4th)',
#    'name': '2014',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': 'San Francisco Caltrain 2 (330 Townsend)',
#    'name': '2014',
#    'value': 12.0},
#   {'city': 'San Francisco',
#    'axis': 'San Francisco City Hall',
#    'name': '2014',
#    'value': 32.0},
#   {'city': 'San Francisco',
#    'axis': 'South Van Ness at Market',
#    'name': '2014',
#    'value': 63.0},
#   {'city': 'San Francisco',
#    'axis': 'Spear at Folsom',
#    'name': '2014',
#    'value': 12.0},
#   {'city': 'San Francisco',
#    'axis': 'Steuart at Market',
#    'name': '2014',
#    'value': 16.0},
#   {'city': 'San Francisco',
#    'axis': 'Temporary Transbay Terminal (Howard at Beale)',
#    'name': '2014',
#    'value': 11.0},
#   {'city': 'San Francisco',
#    'axis': 'Townsend at 7th',
#    'name': '2014',
#    'value': 12.0},
#   {'city': 'San Francisco',
#    'axis': 'Washington at Kearney',
#    'name': '2014',
#    'value': 32.0},
#   {'city': 'San Francisco',
#    'axis': 'Yerba Buena Center of the Arts (3rd @ Howard)',
#    'name': '2014',
#    'value': 15.0},
#   {'city': 'San Jose',
#    'axis': 'Adobe on Almaden',
#    'name': '2014',
#    'value': 14.0},
#   {'city': 'San Jose',
#    'axis': 'Arena Green / SAP Center',
#    'name': '2014',
#    'value': 34.0},
#   {'city': 'San Jose', 'axis': 'Japantown', 'name': '2014', 'value': 41.0},
#   {'city': 'San Jose', 'axis': 'MLK Library', 'name': '2014', 'value': 31.0},
#   {'city': 'San Jose',
#    'axis': 'Paseo de San Antonio',
#    'name': '2014',
#    'value': 30.0},
#   {'city': 'San Jose', 'axis': 'Ryland Park', 'name': '2014', 'value': 23.0},
#   {'city': 'San Jose',
#    'axis': 'SJSU - San Salvador at 9th',
#    'name': '2014',
#    'value': 16.0},
#   {'city': 'San Jose',
#    'axis': 'SJSU 4th at San Carlos',
#    'name': '2014',
#    'value': 35.0},
#   {'city': 'San Jose',
#    'axis': 'San Jose City Hall',
#    'name': '2014',
#    'value': 17.0},
#   {'city': 'San Jose',
#    'axis': 'San Jose Civic Center',
#    'name': '2014',
#    'value': 59.0},
#   {'city': 'San Jose',
#    'axis': 'San Jose Diridon Caltrain Station',
#    'name': '2014',
#    'value': 14.0},
#   {'city': 'San Jose',
#    'axis': 'San Pedro Square',
#    'name': '2014',
#    'value': 16.0},
#   {'city': 'San Jose',
#    'axis': 'San Salvador at 1st',
#    'name': '2014',
#    'value': 18.0},
#   {'city': 'San Jose',
#    'axis': 'Santa Clara County Civic Center',
#    'name': '2014',
#    'value': 23.0},
#   {'city': 'San Jose',
#    'axis': 'Santa Clara at Almaden',
#    'name': '2014',
#    'value': 16.0},
#   {'city': 'San Jose',
#    'axis': 'St James Park',
#    'name': '2014',
#    'value': 16.0}],
#  [{'city': 'Mountain View',
#    'axis': 'Castro Street and El Camino Real',
#    'name': '2015',
#    'value': 32.0},
#   {'city': 'Mountain View',
#    'axis': 'Evelyn Park and Ride',
#    'name': '2015',
#    'value': 18.0},
#   {'city': 'Mountain View',
#    'axis': 'Mountain View Caltrain Station',
#    'name': '2015',
#    'value': 21.0},
#   {'city': 'Mountain View',
#    'axis': 'Mountain View City Hall',
#    'name': '2015',
#    'value': 18.0},
#   {'city': 'Mountain View',
#    'axis': 'Rengstorff Avenue / California Street',
#    'name': '2015',
#    'value': 31.0},
#   {'city': 'Mountain View',
#    'axis': 'San Antonio Caltrain Station',
#    'name': '2015',
#    'value': 26.0},
#   {'city': 'Mountain View',
#    'axis': 'San Antonio Shopping Center',
#    'name': '2015',
#    'value': 60.0},
#   {'city': 'Palo Alto',
#    'axis': 'California Ave Caltrain Station',
#    'name': '2015',
#    'value': 74.0},
#   {'city': 'Palo Alto',
#    'axis': 'Cowper at University',
#    'name': '2015',
#    'value': 45.0},
#   {'city': 'Palo Alto',
#    'axis': 'Palo Alto Caltrain Station',
#    'name': '2015',
#    'value': 55.0},
#   {'city': 'Palo Alto',
#    'axis': 'Park at Olive',
#    'name': '2015',
#    'value': 86.0},
#   {'city': 'Palo Alto',
#    'axis': 'University and Emerson',
#    'name': '2015',
#    'value': 163.0},
#   {'city': 'Redwood City',
#    'axis': 'Franklin at Maple',
#    'name': '2015',
#    'value': 46.0},
#   {'city': 'Redwood City',
#    'axis': 'Mezes Park',
#    'name': '2015',
#    'value': 42.0},
#   {'city': 'Redwood City',
#    'axis': 'Redwood City Caltrain Station',
#    'name': '2015',
#    'value': 24.0},
#   {'city': 'Redwood City',
#    'axis': 'Redwood City Medical Center',
#    'name': '2015',
#    'value': 104.0},
#   {'city': 'Redwood City',
#    'axis': 'Redwood City Public Library',
#    'name': '2015',
#    'value': 53.0},
#   {'city': 'Redwood City',
#    'axis': 'San Mateo County Center',
#    'name': '2015',
#    'value': 39.0},
#   {'city': 'Redwood City',
#    'axis': 'Stanford in Redwood City',
#    'name': '2015',
#    'value': 18.0},
#   {'city': 'San Francisco',
#    'axis': '2nd at Folsom',
#    'name': '2015',
#    'value': 9.0},
#   {'city': 'San Francisco',
#    'axis': '2nd at South Park',
#    'name': '2015',
#    'value': 11.0},
#   {'city': 'San Francisco',
#    'axis': '2nd at Townsend',
#    'name': '2015',
#    'value': 12.0},
#   {'city': 'San Francisco',
#    'axis': '5th at Howard',
#    'name': '2015',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': 'Beale at Market',
#    'name': '2015',
#    'value': 12.0},
#   {'city': 'San Francisco',
#    'axis': 'Broadway St at Battery St',
#    'name': '2015',
#    'value': 13.0},
#   {'city': 'San Francisco',
#    'axis': 'Civic Center BART (7th at Market)',
#    'name': '2015',
#    'value': 16.0},
#   {'city': 'San Francisco',
#    'axis': 'Clay at Battery',
#    'name': '2015',
#    'value': 15.0},
#   {'city': 'San Francisco',
#    'axis': 'Commercial at Montgomery',
#    'name': '2015',
#    'value': 13.0},
#   {'city': 'San Francisco',
#    'axis': 'Davis at Jackson',
#    'name': '2015',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': 'Embarcadero at Bryant',
#    'name': '2015',
#    'value': 15.0},
#   {'city': 'San Francisco',
#    'axis': 'Embarcadero at Folsom',
#    'name': '2015',
#    'value': 13.0},
#   {'city': 'San Francisco',
#    'axis': 'Embarcadero at Sansome',
#    'name': '2015',
#    'value': 21.0},
#   {'city': 'San Francisco',
#    'axis': 'Embarcadero at Vallejo',
#    'name': '2015',
#    'value': 27.0},
#   {'city': 'San Francisco',
#    'axis': 'Golden Gate at Polk',
#    'name': '2015',
#    'value': 18.0},
#   {'city': 'San Francisco',
#    'axis': 'Grant Avenue at Columbus Avenue',
#    'name': '2015',
#    'value': 18.0},
#   {'city': 'San Francisco',
#    'axis': 'Harry Bridges Plaza (Ferry Building)',
#    'name': '2015',
#    'value': 22.0},
#   {'city': 'San Francisco',
#    'axis': 'Howard at 2nd',
#    'name': '2015',
#    'value': 12.0},
#   {'city': 'San Francisco',
#    'axis': 'Market at 10th',
#    'name': '2015',
#    'value': 16.0},
#   {'city': 'San Francisco',
#    'axis': 'Market at 4th',
#    'name': '2015',
#    'value': 19.0},
#   {'city': 'San Francisco',
#    'axis': 'Market at Sansome',
#    'name': '2015',
#    'value': 17.0},
#   {'city': 'San Francisco',
#    'axis': 'Mechanics Plaza (Market at Battery)',
#    'name': '2015',
#    'value': 16.0},
#   {'city': 'San Francisco',
#    'axis': 'Post at Kearney',
#    'name': '2015',
#    'value': 15.0},
#   {'city': 'San Francisco',
#    'axis': 'Powell Street BART',
#    'name': '2015',
#    'value': 22.0},
#   {'city': 'San Francisco',
#    'axis': 'Powell at Post (Union Square)',
#    'name': '2015',
#    'value': 20.0},
#   {'city': 'San Francisco',
#    'axis': 'San Francisco Caltrain (Townsend at 4th)',
#    'name': '2015',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': 'San Francisco Caltrain 2 (330 Townsend)',
#    'name': '2015',
#    'value': 11.0},
#   {'city': 'San Francisco',
#    'axis': 'San Francisco City Hall',
#    'name': '2015',
#    'value': 27.0},
#   {'city': 'San Francisco',
#    'axis': 'South Van Ness at Market',
#    'name': '2015',
#    'value': 15.0},
#   {'city': 'San Francisco',
#    'axis': 'Spear at Folsom',
#    'name': '2015',
#    'value': 15.0},
#   {'city': 'San Francisco',
#    'axis': 'Steuart at Market',
#    'name': '2015',
#    'value': 14.0},
#   {'city': 'San Francisco',
#    'axis': 'Temporary Transbay Terminal (Howard at Beale)',
#    'name': '2015',
#    'value': 10.0},
#   {'city': 'San Francisco',
#    'axis': 'Townsend at 7th',
#    'name': '2015',
#    'value': 10.0},
#   {'city': 'San Francisco',
#    'axis': 'Washington at Kearney',
#    'name': '2015',
#    'value': 22.0},
#   {'city': 'San Francisco',
#    'axis': 'Yerba Buena Center of the Arts (3rd @ Howard)',
#    'name': '2015',
#    'value': 14.0},
#   {'city': 'San Jose',
#    'axis': 'Adobe on Almaden',
#    'name': '2015',
#    'value': 30.0},
#   {'city': 'San Jose',
#    'axis': 'Arena Green / SAP Center',
#    'name': '2015',
#    'value': 30.0},
#   {'city': 'San Jose', 'axis': 'Japantown', 'name': '2015', 'value': 31.0},
#   {'city': 'San Jose', 'axis': 'MLK Library', 'name': '2015', 'value': 18.0},
#   {'city': 'San Jose',
#    'axis': 'Paseo de San Antonio',
#    'name': '2015',
#    'value': 16.0},
#   {'city': 'San Jose', 'axis': 'Ryland Park', 'name': '2015', 'value': 12.0},
#   {'city': 'San Jose',
#    'axis': 'SJSU - San Salvador at 9th',
#    'name': '2015',
#    'value': 25.0},
#   {'city': 'San Jose',
#    'axis': 'SJSU 4th at San Carlos',
#    'name': '2015',
#    'value': 14.0},
#   {'city': 'San Jose',
#    'axis': 'San Jose City Hall',
#    'name': '2015',
#    'value': 16.0},
#   {'city': 'San Jose',
#    'axis': 'San Jose Civic Center',
#    'name': '2015',
#    'value': 92.0},
#   {'city': 'San Jose',
#    'axis': 'San Jose Diridon Caltrain Station',
#    'name': '2015',
#    'value': 15.0},
#   {'city': 'San Jose',
#    'axis': 'San Pedro Square',
#    'name': '2015',
#    'value': 35.0},
#   {'city': 'San Jose',
#    'axis': 'San Salvador at 1st',
#    'name': '2015',
#    'value': 38.0},
#   {'city': 'San Jose',
#    'axis': 'Santa Clara County Civic Center',
#    'name': '2015',
#    'value': 28.0},
#   {'city': 'San Jose',
#    'axis': 'Santa Clara at Almaden',
#    'name': '2015',
#    'value': 16.0},
#   {'city': 'San Jose',
#    'axis': 'St James Park',
#    'name': '2015',
#    'value': 16.0}]]

# %%
# The database URI
engine = create_engine("sqlite:///../db/database.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save reference to the table
Trip = Base.classes.trip
Station = Base.classes.station

# Create our session (link) from Python to the DB
session = Session(engine)

# %%
dist_city_sql = (f'SELECT DISTINCT city FROM station ')

dist_city = pd.read_sql(dist_city_sql, engine.connect())
dist_city_list = dist_city["city"].values.tolist()
dist_city_list
# Out:
# ['San Jose', 'Redwood City', 'Mountain View', 'Palo Alto', 'San Francisco']

# %%
results = session.query(Station.city).distinct()
cities = [result[0] for result in results]
  
print(cities)
    #return render_template("index.html", cities=cities)
# Out:
# ['San Jose', 'Redwood City', 'Mountain View', 'Palo Alto', 'San Francisco']

# %%
stations = ['Clay at Battery', 'Davis at Jackson', 'Commercial at Montgomery',
       'Washington at Kearney', 'Post at Kearney',
       'Embarcadero at Vallejo', 'Spear at Folsom',
       'Harry Bridges Plaza (Ferry Building)', 'Embarcadero at Folsom',
       'Powell Street BART', 'Embarcadero at Bryant',
       'Temporary Transbay Terminal (Howard at Beale)', 'Beale at Market',
       '5th at Howard', 'San Francisco City Hall', 'Golden Gate at Polk',
       'Embarcadero at Sansome', '2nd at Townsend', '2nd at Folsom',
       'Howard at 2nd', '2nd at South Park', 'Townsend at 7th',
       'South Van Ness at Market', 'Market at 10th',
       'Yerba Buena Center of the Arts (3rd @ Howard)',
       'San Francisco Caltrain 2 (330 Townsend)',
       'San Francisco Caltrain (Townsend at 4th)',
       'Powell at Post (Union Square)',
       'Civic Center BART (7th at Market)',
       'Grant Avenue at Columbus Avenue', 'Steuart at Market',
       'Mechanics Plaza (Market at Battery)', 'Market at 4th',
       'Market at Sansome', 'Broadway St at Battery St']


results = session.query(Trip.start_station_name, func.count(Trip.start_station_id))
.filter(Trip.start_station_name.in_(stations)).group_by(Trip.start_station_name)
.order_by(func.count(Trip.start_station_id).desc()).all()

# %%
results
# Out:
# [('San Francisco Caltrain (Townsend at 4th)', 49092),
#  ('San Francisco Caltrain 2 (330 Townsend)', 33742),
#  ('Harry Bridges Plaza (Ferry Building)', 32934),
#  ('Embarcadero at Sansome', 27713),
#  ('Temporary Transbay Terminal (Howard at Beale)', 26089),
#  ('2nd at Townsend', 25837),
#  ('Steuart at Market', 24838),
#  ('Market at Sansome', 24172),
#  ('Townsend at 7th', 23724),
#  ('Market at 10th', 20272),
#  ('Market at 4th', 20165),
#  ('2nd at South Park', 18496),
#  ('Powell Street BART', 18378),
#  ('Grant Avenue at Columbus Avenue', 16306),
#  ('2nd at Folsom', 15940),
#  ('Beale at Market', 15709),
#  ('Embarcadero at Bryant', 14811),
#  ('Civic Center BART (7th at Market)', 14102),
#  ('Embarcadero at Folsom', 14054),
#  ('5th at Howard', 13526),
#  ('Howard at 2nd', 13163),
#  ('South Van Ness at Market', 12880),
#  ('Powell at Post (Union Square)', 12496),
#  ('Mechanics Plaza (Market at Battery)', 12224),
#  ('Spear at Folsom', 11949),
#  ('Commercial at Montgomery', 11888),
#  ('Yerba Buena Center of the Arts (3rd @ Howard)', 11251),
#  ('Embarcadero at Vallejo', 10592),
#  ('Broadway St at Battery St', 10310),
#  ('Clay at Battery', 9994),
#  ('Davis at Jackson', 9957),
#  ('Golden Gate at Polk', 7342),
#  ('San Francisco City Hall', 4535),
#  ('Post at Kearney', 2503),
#  ('Washington at Kearney', 1472)]

# %%
station_ct_sql =('SELECT city, start_station_name, COUNT(start_station_id) as ct '
                 'FROM trip JOIN station on trip.start_station_id = station.id '
                 'GROUP BY city, start_station_name')

station_ct = pd.read_sql(station_ct_sql, engine.connect())

# %%
station_ct_list = station_ct.to_dict('records')
station_ct_list
# Out:
# [{'city': 'Mountain View',
#   'start_station_name': 'Castro Street and El Camino Real',
#   'ct': 2035},
#  {'city': 'Mountain View',
#   'start_station_name': 'Evelyn Park and Ride',
#   'ct': 1667},
#  {'city': 'Mountain View',
#   'start_station_name': 'Mountain View Caltrain Station',
#   'ct': 6544},
#  {'city': 'Mountain View',
#   'start_station_name': 'Mountain View City Hall',
#   'ct': 2984},
#  {'city': 'Mountain View',
#   'start_station_name': 'Rengstorff Avenue / California Street',
#   'ct': 1129},
#  {'city': 'Mountain View',
#   'start_station_name': 'San Antonio Caltrain Station',
#   'ct': 1990},
#  {'city': 'Mountain View',
#   'start_station_name': 'San Antonio Shopping Center',
#   'ct': 1818},
#  {'city': 'Palo Alto',
#   'start_station_name': 'California Ave Caltrain Station',
#   'ct': 1026},
#  {'city': 'Palo Alto',
#   'start_station_name': 'Cowper at University',
#   'ct': 1374},
#  {'city': 'Palo Alto',
#   'start_station_name': 'Palo Alto Caltrain Station',
#   'ct': 2111},
#  {'city': 'Palo Alto', 'start_station_name': 'Park at Olive', 'ct': 750},
#  {'city': 'Palo Alto',
#   'start_station_name': 'University and Emerson',
#   'ct': 1512},
#  {'city': 'Redwood City', 'start_station_name': 'Broadway at Main', 'ct': 67},
#  {'city': 'Redwood City',
#   'start_station_name': 'Franklin at Maple',
#   'ct': 224},
#  {'city': 'Redwood City', 'start_station_name': 'Mezes Park', 'ct': 341},
#  {'city': 'Redwood City',
#   'start_station_name': 'Redwood City Caltrain Station',
#   'ct': 1554},
#  {'city': 'Redwood City',
#   'start_station_name': 'Redwood City Medical Center',
#   'ct': 311},
#  {'city': 'Redwood City',
#   'start_station_name': 'Redwood City Public Library',
#   'ct': 213},
#  {'city': 'Redwood City',
#   'start_station_name': 'San Mateo County Center',
#   'ct': 287},
#  {'city': 'Redwood City',
#   'start_station_name': 'Stanford in Redwood City',
#   'ct': 436},
#  {'city': 'San Francisco', 'start_station_name': '2nd at Folsom', 'ct': 15940},
#  {'city': 'San Francisco',
#   'start_station_name': '2nd at South Park',
#   'ct': 18496},
#  {'city': 'San Francisco',
#   'start_station_name': '2nd at Townsend',
#   'ct': 25837},
#  {'city': 'San Francisco', 'start_station_name': '5th at Howard', 'ct': 13526},
#  {'city': 'San Francisco',
#   'start_station_name': 'Beale at Market',
#   'ct': 15709},
#  {'city': 'San Francisco',
#   'start_station_name': 'Broadway St at Battery St',
#   'ct': 10310},
#  {'city': 'San Francisco',
#   'start_station_name': 'Civic Center BART (7th at Market)',
#   'ct': 14102},
#  {'city': 'San Francisco',
#   'start_station_name': 'Clay at Battery',
#   'ct': 9994},
#  {'city': 'San Francisco',
#   'start_station_name': 'Commercial at Montgomery',
#   'ct': 11888},
#  {'city': 'San Francisco',
#   'start_station_name': 'Davis at Jackson',
#   'ct': 9957},
#  {'city': 'San Francisco',
#   'start_station_name': 'Embarcadero at Bryant',
#   'ct': 14811},
#  {'city': 'San Francisco',
#   'start_station_name': 'Embarcadero at Folsom',
#   'ct': 14054},
#  {'city': 'San Francisco',
#   'start_station_name': 'Embarcadero at Sansome',
#   'ct': 27713},
#  {'city': 'San Francisco',
#   'start_station_name': 'Embarcadero at Vallejo',
#   'ct': 10592},
#  {'city': 'San Francisco',
#   'start_station_name': 'Golden Gate at Polk',
#   'ct': 7342},
#  {'city': 'San Francisco',
#   'start_station_name': 'Grant Avenue at Columbus Avenue',
#   'ct': 16306},
#  {'city': 'San Francisco',
#   'start_station_name': 'Harry Bridges Plaza (Ferry Building)',
#   'ct': 32934},
#  {'city': 'San Francisco', 'start_station_name': 'Howard at 2nd', 'ct': 13163},
#  {'city': 'San Francisco',
#   'start_station_name': 'Market at 10th',
#   'ct': 20272},
#  {'city': 'San Francisco', 'start_station_name': 'Market at 4th', 'ct': 20165},
#  {'city': 'San Francisco',
#   'start_station_name': 'Market at Sansome',
#   'ct': 24172},
#  {'city': 'San Francisco',
#   'start_station_name': 'Mechanics Plaza (Market at Battery)',
#   'ct': 12224},
#  {'city': 'San Francisco',
#   'start_station_name': 'Post at Kearney',
#   'ct': 2503},
#  {'city': 'San Francisco', 'start_station_name': 'Post at Kearny', 'ct': 6960},
#  {'city': 'San Francisco',
#   'start_station_name': 'Powell Street BART',
#   'ct': 18378},
#  {'city': 'San Francisco',
#   'start_station_name': 'Powell at Post (Union Square)',
#   'ct': 12496},
#  {'city': 'San Francisco',
#   'start_station_name': 'San Francisco Caltrain (Townsend at 4th)',
#   'ct': 49092},
#  {'city': 'San Francisco',
#   'start_station_name': 'San Francisco Caltrain 2 (330 Townsend)',
#   'ct': 33742},
#  {'city': 'San Francisco',
#   'start_station_name': 'San Francisco City Hall',
#   'ct': 4535},
#  {'city': 'San Francisco',
#   'start_station_name': 'South Van Ness at Market',
#   'ct': 12880},
#  {'city': 'San Francisco',
#   'start_station_name': 'Spear at Folsom',
#   'ct': 11949},
#  {'city': 'San Francisco',
#   'start_station_name': 'Steuart at Market',
#   'ct': 24838},
#  {'city': 'San Francisco',
#   'start_station_name': 'Temporary Transbay Terminal (Howard at Beale)',
#   'ct': 26089},
#  {'city': 'San Francisco',
#   'start_station_name': 'Townsend at 7th',
#   'ct': 23724},
#  {'city': 'San Francisco',
#   'start_station_name': 'Washington at Kearney',
#   'ct': 1472},
#  {'city': 'San Francisco',
#   'start_station_name': 'Washington at Kearny',
#   'ct': 4292},
#  {'city': 'San Francisco',
#   'start_station_name': 'Yerba Buena Center of the Arts (3rd @ Howard)',
#   'ct': 11251},
#  {'city': 'San Jose', 'start_station_name': 'Adobe on Almaden', 'ct': 1257},
#  {'city': 'San Jose',
#   'start_station_name': 'Arena Green / SAP Center',
#   'ct': 1496},
#  {'city': 'San Jose', 'start_station_name': 'Japantown', 'ct': 1910},
#  {'city': 'San Jose', 'start_station_name': 'MLK Library', 'ct': 2034},
#  {'city': 'San Jose',
#   'start_station_name': 'Paseo de San Antonio',
#   'ct': 2233},
#  {'city': 'San Jose', 'start_station_name': 'Ryland Park', 'ct': 1747},
#  {'city': 'San Jose',
#   'start_station_name': 'SJSU - San Salvador at 9th',
#   'ct': 1473},
#  {'city': 'San Jose',
#   'start_station_name': 'SJSU 4th at San Carlos',
#   'ct': 1170},
#  {'city': 'San Jose', 'start_station_name': 'San Jose City Hall', 'ct': 2393},
#  {'city': 'San Jose',
#   'start_station_name': 'San Jose Civic Center',
#   'ct': 1594},
#  {'city': 'San Jose',
#   'start_station_name': 'San Jose Diridon Caltrain Station',
#   'ct': 9558},
#  {'city': 'San Jose',
#   'start_station_name': 'San Jose Government Center',
#   'ct': 23},
#  {'city': 'San Jose', 'start_station_name': 'San Pedro Square', 'ct': 2917},
#  {'city': 'San Jose', 'start_station_name': 'San Salvador at 1st', 'ct': 1692},
#  {'city': 'San Jose',
#   'start_station_name': 'Santa Clara County Civic Center',
#   'ct': 840},
#  {'city': 'San Jose',
#   'start_station_name': 'Santa Clara at Almaden',
#   'ct': 3861},
#  {'city': 'San Jose', 'start_station_name': 'St James Park', 'ct': 1680}]

# %%
city='San Francisco'
station_ct_select = station_ct[station_ct["city"]==city].nlargest(10, 'ct')
station_ct_select
# Out:
#              city                             start_station_name     ct
# 46  San Francisco       San Francisco Caltrain (Townsend at 4th)  49092
# 47  San Francisco        San Francisco Caltrain 2 (330 Townsend)  33742
# 36  San Francisco           Harry Bridges Plaza (Ferry Building)  32934
# 32  San Francisco                         Embarcadero at Sansome  27713
# 52  San Francisco  Temporary Transbay Terminal (Howard at Beale)  26089
# 22  San Francisco                                2nd at Townsend  25837
# 51  San Francisco                              Steuart at Market  24838
# 40  San Francisco                              Market at Sansome  24172
# 53  San Francisco                                Townsend at 7th  23724
# 38  San Francisco                                 Market at 10th  20272

# %%
station_ct_select_list = station_ct_select.to_dict('records')
station_ct_select_list
# Out:
# [{'city': 'Palo Alto',
#   'start_station_name': 'California Ave Caltrain Station',
#   'ct': 1026},
#  {'city': 'Palo Alto',
#   'start_station_name': 'Cowper at University',
#   'ct': 1374},
#  {'city': 'Palo Alto',
#   'start_station_name': 'Palo Alto Caltrain Station',
#   'ct': 2111},
#  {'city': 'Palo Alto', 'start_station_name': 'Park at Olive', 'ct': 750},
#  {'city': 'Palo Alto',
#   'start_station_name': 'University and Emerson',
#   'ct': 1512}]

# %%
#station_names = station_ct_select_list["start_station_name"].values.tolist()

station_names = station_ct_select["start_station_name"].values.tolist()
start_station_id = station_ct_select["ct"].values.tolist()

# %%
#popular end station

station_end_ct_sql =('SELECT city, end_station_name, COUNT(end_station_id) as ct '
                 'FROM trip JOIN station on trip.start_station_id = station.id '
                 'GROUP BY city, end_station_name')

station_end_ct = pd.read_sql(station_end_ct_sql, engine.connect())
station_end_ct
# Out:
#               city                               end_station_name     ct
# 0    Mountain View                       Arena Green / SAP Center      1
# 1    Mountain View                California Ave Caltrain Station    108
# 2    Mountain View               Castro Street and El Camino Real   1809
# 3    Mountain View              Civic Center BART (7th at Market)      1
# 4    Mountain View                           Cowper at University      9
# 5    Mountain View                           Evelyn Park and Ride   1364
# 6    Mountain View                              Franklin at Maple      1
# 7    Mountain View                                  Howard at 2nd      2
# 8    Mountain View                                      Japantown      3
# 9    Mountain View                                 Market at 10th      2
# 10   Mountain View                                  Market at 4th      2
# 11   Mountain View                 Mountain View Caltrain Station   6654
# 12   Mountain View                        Mountain View City Hall   3269
# 13   Mountain View                     Palo Alto Caltrain Station     40
# 14   Mountain View                                  Park at Olive    108
# 15   Mountain View                  Redwood City Caltrain Station      1
# 16   Mountain View          Rengstorff Avenue / California Street   1042
# 17   Mountain View                   San Antonio Caltrain Station   1893
# 18   Mountain View                    San Antonio Shopping Center   1715
# 19   Mountain View       San Francisco Caltrain (Townsend at 4th)      2
# 20   Mountain View                          San Jose Civic Center      1
# 21   Mountain View              San Jose Diridon Caltrain Station      4
# 22   Mountain View                            San Salvador at 1st      1
# 23   Mountain View                Santa Clara County Civic Center      3
# 24   Mountain View                                  St James Park      2
# 25   Mountain View                       Stanford in Redwood City      2
# 26   Mountain View                         University and Emerson    128
# 27       Palo Alto                                Beale at Market      1
# 28       Palo Alto                               Broadway at Main      3
# 29       Palo Alto                California Ave Caltrain Station   1025
# ..             ...                                            ...    ...
# 110  San Francisco                                Townsend at 7th  26637
# 111  San Francisco                         University and Emerson      3
# 112  San Francisco                          Washington at Kearney   1772
# 113  San Francisco                           Washington at Kearny   5461
# 114  San Francisco  Yerba Buena Center of the Arts (3rd @ Howard)  12140
# 115       San Jose                               Adobe on Almaden   1169
# 116       San Jose                       Arena Green / SAP Center   1367
# 117       San Jose                California Ave Caltrain Station      1
# 118       San Jose              Civic Center BART (7th at Market)      1
# 119       San Jose                           Cowper at University      3
# 120       San Jose                                      Japantown   2197
# 121       San Jose                                    MLK Library   2508
# 122       San Jose                                  Market at 4th      2
# 123       San Jose                 Mountain View Caltrain Station      9
# 124       San Jose                           Paseo de San Antonio   2497
# 125       San Jose          Rengstorff Avenue / California Street      2
# 126       San Jose                                    Ryland Park   1441
# 127       San Jose                     SJSU - San Salvador at 9th   1472
# 128       San Jose                         SJSU 4th at San Carlos   1437
# 129       San Jose                    San Antonio Shopping Center      3
# 130       San Jose       San Francisco Caltrain (Townsend at 4th)      1
# 131       San Jose                             San Jose City Hall   1657
# 132       San Jose                          San Jose Civic Center   1785
# 133       San Jose              San Jose Diridon Caltrain Station   9410
# 134       San Jose                     San Jose Government Center     23
# 135       San Jose                               San Pedro Square   3163
# 136       San Jose                            San Salvador at 1st   1706
# 137       San Jose                Santa Clara County Civic Center    833
# 138       San Jose                         Santa Clara at Almaden   3705
# 139       San Jose                                  St James Park   1486
#
# [140 rows x 3 columns]

# %%
city='San Francisco'
station_end_ct_select = station_end_ct[station_end_ct["city"]==city].nlargest(10, 'ct')
station_end_ct_select
# Out:
#               city                               end_station_name     ct
# 99   San Francisco       San Francisco Caltrain (Townsend at 4th)  63167
# 100  San Francisco        San Francisco Caltrain 2 (330 Townsend)  35117
# 83   San Francisco           Harry Bridges Plaza (Ferry Building)  33193
# 79   San Francisco                         Embarcadero at Sansome  30796
# 69   San Francisco                                2nd at Townsend  28529
# 87   San Francisco                              Market at Sansome  28032
# 110  San Francisco                                Townsend at 7th  26637
# 108  San Francisco                              Steuart at Market  25025
# 109  San Francisco  Temporary Transbay Terminal (Howard at Beale)  23080
# 86   San Francisco                                  Market at 4th  19911

# %%
end_station_names = station_end_ct_select["end_station_name"].values.tolist()
end_start_station_id = station_end_ct_select["ct"].values.tolist()

# %%
end_station_names
# Out:
# ['San Francisco Caltrain (Townsend at 4th)',
#  'San Francisco Caltrain 2 (330 Townsend)',
#  'Harry Bridges Plaza (Ferry Building)',
#  'Embarcadero at Sansome',
#  '2nd at Townsend',
#  'Market at Sansome',
#  'Townsend at 7th',
#  'Steuart at Market',
#  'Temporary Transbay Terminal (Howard at Beale)',
#  'Market at 4th']

# %%
results = session.query(Trip.start_station_name, func.count(Trip.start_station_id))
.group_by(Trip.start_station_name).order_by(func.count(Trip.start_station_id).desc()).limit(20).all()

# %%
top_start_sql = ('SELECT start_station_name, COUNT(start_station_id) as ct FROM trip GROUP BY start_station_name')
top_start = pd.read_sql(top_start_sql, engine.connect())
top_start_20 = top_start.nlargest(20, 'ct')

start_station = top_start_20["start_station_name"].values.tolist()
start_ct = top_start_20["ct"].values.tolist()

# %%
top_end_sql = ('SELECT end_station_name, COUNT(end_station_id) as ct FROM trip GROUP BY end_station_name')
top_end = pd.read_sql(top_end_sql, engine.connect())
top_end_20 = top_end.nlargest(20, 'ct')

end_station = top_end_20["end_station_name"].values.tolist()
end_ct = top_end_20["ct"].values.tolist()

# %%
end_station
# Out:
# ['San Francisco Caltrain (Townsend at 4th)',
#  'San Francisco Caltrain 2 (330 Townsend)',
#  'Harry Bridges Plaza (Ferry Building)',
#  'Embarcadero at Sansome',
#  '2nd at Townsend',
#  'Market at Sansome',
#  'Townsend at 7th',
#  'Steuart at Market',
#  'Temporary Transbay Terminal (Howard at Beale)',
#  'Market at 4th',
#  'Powell Street BART',
#  'Market at 10th',
#  '2nd at South Park',
#  '5th at Howard',
#  'Civic Center BART (7th at Market)',
#  'Howard at 2nd',
#  'Embarcadero at Folsom',
#  'Embarcadero at Bryant',
#  'Embarcadero at Vallejo',
#  'Beale at Market']

# %%
Base.classes.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-b3e5558f5eed> in <module>()
# ----> 1 Base.classes.keys()
#
# AttributeError: type object 'Base' has no attribute 'classes'

# %%
from sqlalchemy import inspect

# %%
inspector = inspect(engine)

for table_name in inspector.get_table_names():
    print(table_name)
# Out:
# station
# status
# trip
# weather

# %%
status = Base.classes.status
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'status'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-1fcc8cf18755> in <module>()
# ----> 1 status = Base.classes.status
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# AttributeError: status

# %%
from sqlalchemy import MetaData
from sqlalchemy import Table

metadata = MetaData()
print(metadata.tables)
# Out:
# immutabledict({})

# %%
metadata.reflect(bind=engine)
print(metadata.tables)
# Out:
# immutabledict({'station': Table('station', MetaData(bind=None), Column('id', INTEGER(), table=<station>, primary_key=True, nullable=False), Column('name', TEXT(), table=<station>), Column('lat', NUMERIC(), table=<station>), Column('long', NUMERIC(), table=<station>), Column('dock_count', INTEGER(), table=<station>), Column('city', TEXT(), table=<station>), Column('installation_date', TEXT(), table=<station>), schema=None), 'status': Table('status', MetaData(bind=None), Column('station_id', INTEGER(), table=<status>), Column('bikes_available', INTEGER(), table=<status>), Column('docks_available', INTEGER(), table=<status>), Column('time', TEXT(), table=<status>), schema=None), 'trip': Table('trip', MetaData(bind=None), Column('id', INTEGER(), table=<trip>, primary_key=True, nullable=False), Column('duration', INTEGER(), table=<trip>), Column('start_date', TEXT(), table=<trip>), Column('start_station_name', TEXT(), table=<trip>), Column('start_station_id', INTEGER(), table=<trip>), Column('end_date', TEXT(), table=<trip>), Column('end_station_name', TEXT(), table=<trip>), Column('end_station_id', INTEGER(), table=<trip>), Column('bike_id', INTEGER(), table=<trip>), Column('subscription_type', TEXT(), table=<trip>), Column('zip_code', INTEGER(), table=<trip>), schema=None), 'weather': Table('weather', MetaData(bind=None), Column('date', TEXT(), table=<weather>), Column('max_temperature_f', INTEGER(), table=<weather>), Column('mean_temperature_f', INTEGER(), table=<weather>), Column('min_temperature_f', INTEGER(), table=<weather>), Column('max_dew_point_f', INTEGER(), table=<weather>), Column('mean_dew_point_f', INTEGER(), table=<weather>), Column('min_dew_point_f', INTEGER(), table=<weather>), Column('max_humidity', INTEGER(), table=<weather>), Column('mean_humidity', INTEGER(), table=<weather>), Column('min_humidity', INTEGER(), table=<weather>), Column('max_sea_level_pressure_inches', NUMERIC(), table=<weather>), Column('mean_sea_level_pressure_inches', NUMERIC(), table=<weather>), Column('min_sea_level_pressure_inches', NUMERIC(), table=<weather>), Column('max_visibility_miles', INTEGER(), table=<weather>), Column('mean_visibility_miles', INTEGER(), table=<weather>), Column('min_visibility_miles', INTEGER(), table=<weather>), Column('max_wind_Speed_mph', INTEGER(), table=<weather>), Column('mean_wind_speed_mph', INTEGER(), table=<weather>), Column('max_gust_speed_mph', INTEGER(), table=<weather>), Column('precipitation_inches', INTEGER(), table=<weather>), Column('cloud_cover', INTEGER(), table=<weather>), Column('events', TEXT(), table=<weather>), Column('wind_dir_degrees', INTEGER(), table=<weather>), Column('zip_code', INTEGER(), table=<weather>), schema=None)})

# %%
statusTable = Table('status', metadata, Column('station_id', Integer, primary_key=True), autoload=True, autoload_with=engine)
for c in statusTable.columns:
    print(c.name)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-44-1178b8ecf802> in <module>()
# ----> 1 statusTable = Table('status', metadata, Column('station_id', Integer, primary_key=True), autoload=True, autoload_with=engine)
#       2 for c in statusTable.columns:
#       3     print(c.name)
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/sql/schema.py in __new__(cls, *args, **kw)
#     436                     "to redefine "
#     437                     "options and columns on an "
# --> 438                     "existing Table object." % key)
#     439             table = metadata.tables[key]
#     440             if extend_existing:
#
# InvalidRequestError: Table 'status' is already defined for this MetaData instance.  Specify 'extend_existing=True' to redefine options and columns on an existing Table object.

# %%
stationTable = Table('station', metadata, autoload=True, autoload_with=engine)
for c in stationTable.columns:
    print(c.name)
# Out:
# id
# name
# lat
# long
# dock_count
# city
# installation_date

# %%
tripTable = Table('trip', metadata, autoload=True, autoload_with=engine)
for c in tripTable.columns:
    print(c.name)
# Out:
# id
# duration
# start_date
# start_station_name
# start_station_id
# end_date
# end_station_name
# end_station_id
# bike_id
# subscription_type
# zip_code

# %%
weatherTable = Table('weather', metadata, autoload=True, autoload_with=engine)
weatherCol = []
for c in weatherTable.columns:
    weatherCol.append(c.name)
# Out:
# ['date']
# ['date', 'max_temperature_f']
# ['date', 'max_temperature_f', 'mean_temperature_f']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches', 'min_sea_level_pressure_inches']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches', 'min_sea_level_pressure_inches', 'max_visibility_miles']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches', 'min_sea_level_pressure_inches', 'max_visibility_miles', 'mean_visibility_miles']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches', 'min_sea_level_pressure_inches', 'max_visibility_miles', 'mean_visibility_miles', 'min_visibility_miles']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches', 'min_sea_level_pressure_inches', 'max_visibility_miles', 'mean_visibility_miles', 'min_visibility_miles', 'max_wind_Speed_mph']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches', 'min_sea_level_pressure_inches', 'max_visibility_miles', 'mean_visibility_miles', 'min_visibility_miles', 'max_wind_Speed_mph', 'mean_wind_speed_mph']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches', 'min_sea_level_pressure_inches', 'max_visibility_miles', 'mean_visibility_miles', 'min_visibility_miles', 'max_wind_Speed_mph', 'mean_wind_speed_mph', 'max_gust_speed_mph']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches', 'min_sea_level_pressure_inches', 'max_visibility_miles', 'mean_visibility_miles', 'min_visibility_miles', 'max_wind_Speed_mph', 'mean_wind_speed_mph', 'max_gust_speed_mph', 'precipitation_inches']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches', 'min_sea_level_pressure_inches', 'max_visibility_miles', 'mean_visibility_miles', 'min_visibility_miles', 'max_wind_Speed_mph', 'mean_wind_speed_mph', 'max_gust_speed_mph', 'precipitation_inches', 'cloud_cover']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches', 'min_sea_level_pressure_inches', 'max_visibility_miles', 'mean_visibility_miles', 'min_visibility_miles', 'max_wind_Speed_mph', 'mean_wind_speed_mph', 'max_gust_speed_mph', 'precipitation_inches', 'cloud_cover', 'events']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches', 'min_sea_level_pressure_inches', 'max_visibility_miles', 'mean_visibility_miles', 'min_visibility_miles', 'max_wind_Speed_mph', 'mean_wind_speed_mph', 'max_gust_speed_mph', 'precipitation_inches', 'cloud_cover', 'events', 'wind_dir_degrees']
# ['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f', 'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f', 'max_humidity', 'mean_humidity', 'min_humidity', 'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches', 'min_sea_level_pressure_inches', 'max_visibility_miles', 'mean_visibility_miles', 'min_visibility_miles', 'max_wind_Speed_mph', 'mean_wind_speed_mph', 'max_gust_speed_mph', 'precipitation_inches', 'cloud_cover', 'events', 'wind_dir_degrees', 'zip_code']

# %%
class status(Base):
    __tablename__ = 'status'
    
    station_id = Column(Integer, primary_key=True)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-53-743989732747> in <module>()
# ----> 1 class status(Base):
#       2     __tablename__ = 'status'
#       3
#       4     station_id = Column(Integer, primary_key=True)
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/ext/declarative/api.py in __init__(cls, classname, bases, dict_)
#      63     def __init__(cls, classname, bases, dict_):
#      64         if '_decl_class_registry' not in cls.__dict__:
# ---> 65             _as_declarative(cls, classname, cls.__dict__)
#      66         type.__init__(cls, classname, bases, dict_)
#      67
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/ext/declarative/base.py in _as_declarative(cls, classname, dict_)
#      86         return
#      87
# ---> 88     _MapperConfig.setup_mapping(cls, classname, dict_)
#      89
#      90
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/ext/declarative/base.py in setup_mapping(cls, cls_, classname, dict_)
#     114         else:
#     115             cfg_cls = _MapperConfig
# --> 116         cfg_cls(cls_, classname, dict_)
#     117
#     118     def __init__(self, cls_, classname, dict_):
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/ext/declarative/base.py in __init__(self, cls_, classname, dict_)
#     142         self._extract_declared_columns()
#     143
# --> 144         self._setup_table()
#     145
#     146         self._setup_inheritance()
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/ext/declarative/base.py in _setup_table(self)
#     435                     tablename, cls.metadata,
#     436                     *(tuple(declared_columns) + tuple(args)),
# --> 437                     **table_kw)
#     438         else:
#     439             table = cls.__table__
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/sql/schema.py in __new__(cls, *args, **kw)
#     436                     "to redefine "
#     437                     "options and columns on an "
# --> 438                     "existing Table object." % key)
#     439             table = metadata.tables[key]
#     440             if extend_existing:
#
# InvalidRequestError: Table 'status' is already defined for this MetaData instance.  Specify 'extend_existing=True' to redefine options and columns on an existing Table object.

# %%
class weather(Base):
    __tablename__ = 'user'

    id = Column(Integer, primary_key=True)
# Out:
# /Users/mochathereal/anaconda3/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:120: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.station, and will be replaced in the string-lookup table.
#   item.__name__
# /Users/mochathereal/anaconda3/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:120: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.trip, and will be replaced in the string-lookup table.
#   item.__name__
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-37-201373d86691> in <module>()
# ----> 1 Base.prepare()
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/ext/automap.py in prepare(cls, engine, reflect, schema, classname_for_table, collection_class, name_for_scalar_relationship, name_for_collection_relationship, generate_relationship)
#     797
#     798         for map_config in _DeferredMapperConfig.classes_for_base(cls):
# --> 799             map_config.map()
#     800
#     801     _sa_decl_prepare = True
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/ext/declarative/base.py in map(self)
#     641     def map(self):
#     642         self._configs.pop(self._cls, None)
# --> 643         return super(_DeferredMapperConfig, self).map()
#     644
#     645
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/ext/declarative/base.py in map(self)
#     574             self.cls,
#     575             self.local_table,
# --> 576             **self.mapper_args
#     577         )
#     578         del self.cls._sa_declared_attr_reg
#
# <string> in mapper(class_, local_table, properties, primary_key, non_primary, inherits, inherit_condition, inherit_foreign_keys, extension, order_by, always_refresh, version_id_col, version_id_generator, polymorphic_on, _polymorphic_map, polymorphic_identity, concrete, with_polymorphic, polymorphic_load, allow_partial_pks, batch, column_prefix, include_properties, exclude_properties, passive_updates, passive_deletes, confirm_deleted_rows, eager_defaults, legacy_is_orphan, _compiled_cache_size)
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/mapper.py in __init__(self, class_, local_table, properties, primary_key, non_primary, inherits, inherit_condition, inherit_foreign_keys, extension, order_by, always_refresh, version_id_col, version_id_generator, polymorphic_on, _polymorphic_map, polymorphic_identity, concrete, with_polymorphic, polymorphic_load, allow_partial_pks, batch, column_prefix, include_properties, exclude_properties, passive_updates, passive_deletes, confirm_deleted_rows, eager_defaults, legacy_is_orphan, _compiled_cache_size)
#     692             self._configure_properties()
#     693             self._configure_polymorphic_setter()
# --> 694             self._configure_pks()
#     695             Mapper._new_mappers = True
#     696             self._log("constructed")
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/orm/mapper.py in _configure_pks(self)
#    1325                 "Mapper %s could not assemble any primary "
#    1326                 "key columns for mapped table '%s'" %
# -> 1327                 (self, self.mapped_table.description))
#    1328         elif self.local_table not in self._pks_by_table and \
#    1329                 isinstance(self.local_table, schema.Table):
#
# ArgumentError: Mapper Mapper|weather|weather could not assemble any primary key columns for mapped table 'weather'

# %%
Base.classes.keys()
# Out:
# ['station', 'trip']
