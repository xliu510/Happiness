# %%
#Import dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import pandas as pd
import csv
import os

# %%
#Import csv data World_Happiness_Report_2015.csv
World_Happiness_Report_2015_csv = os.path.join("World_Happiness_Report_2015.csv")
World_Happiness_Report_2015_df = pd.read_csv(World_Happiness_Report_2015_csv)
World_Happiness_Report_2015_df.rename(columns={'Region':'Region_2015','Happiness Rank':'Happiness_Rank_2015','Happiness Score':'Happiness_Score_2015','Standard Error':'Standard_Error_2015','Economy (GDP per Capita)':'GDP_per_Capita_2015','Family':'Family_2015','Health (Life Expectancy)':'Health_2015','Freedom':'Freedom_2015','Trust (Government Corruption)':'Government_Trust_2015','Generosity':'Generosity_2015','Dystopia Residual':'Dystopia_Residual_2015'
}, inplace=True)
World_Happiness_Report_2015_df.head()
# Out:
#        Country     Region_2015  Happiness_Rank_2015  Happiness_Score_2015  \
# 0  Switzerland  Western Europe                    1                 7.587
# 1      Iceland  Western Europe                    2                 7.561
# 2      Denmark  Western Europe                    3                 7.527
# 3       Norway  Western Europe                    4                 7.522
# 4       Canada   North America                    5                 7.427
#
#    Standard_Error_2015  GDP_per_Capita_2015  Family_2015  Health_2015  \
# 0              0.03411              1.39651      1.34951      0.94143
# 1              0.04884              1.30232      1.40223      0.94784
# 2              0.03328              1.32548      1.36058      0.87464
# 3              0.03880              1.45900      1.33095      0.88521
# 4              0.03553              1.32629      1.32261      0.90563
#
#    Freedom_2015  Government_Trust_2015  Generosity_2015  \
# 0       0.66557                0.41978          0.29678
# 1       0.62877                0.14145          0.43630
# 2       0.64938                0.48357          0.34139
# 3       0.66973                0.36503          0.34699
# 4       0.63297                0.32957          0.45811
#
#    Dystopia_Residual_2015
# 0                 2.51738
# 1                 2.70201
# 2                 2.49204
# 3                 2.46531
# 4                 2.45176

# %%
#Import csv data World_Happiness_Report_2016.csv
World_Happiness_Report_2016_csv = os.path.join("World_Happiness_Report_2016.csv")
World_Happiness_Report_2016_df = pd.read_csv(World_Happiness_Report_2016_csv)
World_Happiness_Report_2016_df.rename(columns={'Region':'Region_2016','Happiness Rank':'Happiness_Rank_2016','Happiness Score':'Happiness_Score_2016','Standard Error':'Standard_Error_2016','Economy (GDP per Capita)':'GDP_per_Capita_2016','Family':'Family_2016','Health (Life Expectancy)':'Health_2016','Freedom':'Freedom_2016','Trust (Government Corruption)':'Government_Trust_2016','Generosity':'Generosity_2016','Dystopia Residual':'Dystopia_Residual_2016'}, inplace=True)
World_Happiness_Report_2016_df.head()
# Out:
#        Country     Region_2016  Happiness_Rank_2016  Happiness_Score_2016  \
# 0      Denmark  Western Europe                    1                 7.526
# 1  Switzerland  Western Europe                    2                 7.509
# 2      Iceland  Western Europe                    3                 7.501
# 3       Norway  Western Europe                    4                 7.498
# 4      Finland  Western Europe                    5                 7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  GDP_per_Capita_2016  \
# 0                      7.460                      7.592              1.44178
# 1                      7.428                      7.590              1.52733
# 2                      7.333                      7.669              1.42666
# 3                      7.421                      7.575              1.57744
# 4                      7.351                      7.475              1.40598
#
#    Family_2016  Health_2016  Freedom_2016  Government_Trust_2016  \
# 0      1.16374      0.79504       0.57941                0.44453
# 1      1.14524      0.86303       0.58557                0.41203
# 2      1.18326      0.86733       0.56624                0.14975
# 3      1.12690      0.79579       0.59609                0.35776
# 4      1.13464      0.81091       0.57104                0.41004
#
#    Generosity_2016  Dystopia_Residual_2016
# 0          0.36171                 2.73939
# 1          0.28083                 2.69463
# 2          0.47678                 2.83137
# 3          0.37895                 2.66465
# 4          0.25492                 2.82596

# %%
#Import csv data World_Happiness_Report_2017.csv
World_Happiness_Report_2017_csv = os.path.join("World_Happiness_Report_2017.csv")
World_Happiness_Report_2017_df = pd.read_csv(World_Happiness_Report_2017_csv)
World_Happiness_Report_2017_df.rename(columns={'Happiness.Rank':'Happiness-Rank_2017','Happiness.Score':'Happiness_Score_2017','Whisker.high':'Whisker_high_2017','Whisker.low':'Whisker_low_2017','Economy..GDP.per.Capita.':'GDP_per_Capita_2017','Family':'Family_2017','Health..Life.Expectancy.':'Health_2017','Freedom':'Freedom_2017','Generosity':'Generosity_2017','Trust..Government.Corruption.':'Government_Trust_2017','Dystopia.Residual':'Dystopia_Residual_2017'}, inplace=True)
World_Happiness_Report_2017_df.head()
# Out:
#        Country  Happiness-Rank_2017  Happiness_Score_2017  Whisker_high_2017  \
# 0       Norway                    1                 7.537           7.594445
# 1      Denmark                    2                 7.522           7.581728
# 2      Iceland                    3                 7.504           7.622030
# 3  Switzerland                    4                 7.494           7.561772
# 4      Finland                    5                 7.469           7.527542
#
#    Whisker_low_2017  GDP_per_Capita_2017  Family_2017  Health_2017  \
# 0          7.479556             1.616463     1.533524     0.796667
# 1          7.462272             1.482383     1.551122     0.792566
# 2          7.385970             1.480633     1.610574     0.833552
# 3          7.426227             1.564980     1.516912     0.858131
# 4          7.410458             1.443572     1.540247     0.809158
#
#    Freedom_2017  Generosity_2017  Government_Trust_2017  \
# 0      0.635423         0.362012               0.315964
# 1      0.626007         0.355280               0.400770
# 2      0.627163         0.475540               0.153527
# 3      0.620071         0.290549               0.367007
# 4      0.617951         0.245483               0.382612
#
#    Dystopia_Residual_2017
# 0                2.277027
# 1                2.313707
# 2                2.322715
# 3                2.276716
# 4                2.430182

# %%
#Merge World_Happiness_Report 2015-2017 data
World_Happiness_Report_2015_2016_df = World_Happiness_Report_2015_df.merge(World_Happiness_Report_2016_df, on=['Country'], how='left')
World_Happiness_Report_2015_2016_2017_df = World_Happiness_Report_2015_2016_df.merge(World_Happiness_Report_2017_df, on=['Country'], how='left')
World_Happiness_Report_2015_2016_2017_df.head()
# Out:
#        Country     Region_2015  Happiness_Rank_2015  Happiness_Score_2015  \
# 0  Switzerland  Western Europe                    1                 7.587
# 1      Iceland  Western Europe                    2                 7.561
# 2      Denmark  Western Europe                    3                 7.527
# 3       Norway  Western Europe                    4                 7.522
# 4       Canada   North America                    5                 7.427
#
#    Standard_Error_2015  GDP_per_Capita_2015  Family_2015  Health_2015  \
# 0              0.03411              1.39651      1.34951      0.94143
# 1              0.04884              1.30232      1.40223      0.94784
# 2              0.03328              1.32548      1.36058      0.87464
# 3              0.03880              1.45900      1.33095      0.88521
# 4              0.03553              1.32629      1.32261      0.90563
#
#    Freedom_2015  Government_Trust_2015           ...            \
# 0       0.66557                0.41978           ...
# 1       0.62877                0.14145           ...
# 2       0.64938                0.48357           ...
# 3       0.66973                0.36503           ...
# 4       0.63297                0.32957           ...
#
#    Happiness_Score_2017  Whisker_high_2017 Whisker_low_2017  \
# 0                 7.494           7.561772         7.426227
# 1                 7.504           7.622030         7.385970
# 2                 7.522           7.581728         7.462272
# 3                 7.537           7.594445         7.479556
# 4                 7.316           7.384403         7.247597
#
#    GDP_per_Capita_2017  Family_2017  Health_2017  Freedom_2017  \
# 0             1.564980     1.516912     0.858131      0.620071
# 1             1.480633     1.610574     0.833552      0.627163
# 2             1.482383     1.551122     0.792566      0.626007
# 3             1.616463     1.533524     0.796667      0.635423
# 4             1.479204     1.481349     0.834558      0.611101
#
#    Generosity_2017  Government_Trust_2017  Dystopia_Residual_2017
# 0         0.290549               0.367007                2.276716
# 1         0.475540               0.153527                2.322715
# 2         0.355280               0.400770                2.313707
# 3         0.362012               0.315964                2.277027
# 4         0.435540               0.287372                2.187264
#
# [5 rows x 35 columns]

# %%
#Import csv data Life_Expectancy_Data.csv
Life_Expectancy_Data_csv = os.path.join("Life_Expectancy_Data.csv")
Life_Expectancy_Data_df = pd.read_csv(Life_Expectancy_Data_csv)
#Loc 2015 data
Life_Expectancy_Data_df_2015 = Life_Expectancy_Data_df.loc[Life_Expectancy_Data_df['Year'] == 2015]
Life_Expectancy_Data_df_2015.head()
# Out:
#                 Country  Year      Status  Life expectancy   Adult Mortality  \
# 0           Afghanistan  2015  Developing              65.0            263.0
# 16              Albania  2015  Developing              77.8             74.0
# 32              Algeria  2015  Developing              75.6             19.0
# 48               Angola  2015  Developing              52.4            335.0
# 64  Antigua and Barbuda  2015  Developing              76.4             13.0
#
#     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0              62     0.01               71.279624         65.0      1154
# 16              0     4.60              364.975229         99.0         0
# 32             21      NaN                0.000000         95.0        63
# 48             66      NaN                0.000000         64.0       118
# 64              0      NaN                0.000000         99.0         0
#
#       ...      Polio  Total expenditure  Diphtheria    HIV/AIDS           GDP  \
# 0     ...        6.0               8.16         65.0        0.1    584.259210
# 16    ...       99.0               6.00         99.0        0.1   3954.227830
# 32    ...       95.0                NaN         95.0        0.1   4132.762920
# 48    ...        7.0                NaN         64.0        1.9   3695.793748
# 64    ...       86.0                NaN         99.0        0.2  13566.954100
#
#     Population   thinness  1-19 years   thinness 5-9 years  \
# 0   33736494.0                   17.2                 17.3
# 16     28873.0                    1.2                  1.3
# 32  39871528.0                    6.0                  5.8
# 48   2785935.0                    8.3                  8.2
# 64         NaN                    3.3                  3.3
#
#     Income composition of resources  Schooling
# 0                             0.479       10.1
# 16                            0.762       14.2
# 32                            0.743       14.4
# 48                            0.531       11.4
# 64                            0.784       13.9
#
# [5 rows x 22 columns]

# %%
#Merge  Life_Expectancy_Data_df_2015 and World_Happiness_Report_2015_df dataframes
World_Happiness_Life_Expectancy_df = World_Happiness_Report_2015_df.merge(Life_Expectancy_Data_df_2015, on=['Country'], how='left')
World_Happiness_Life_Expectancy_df.describe()
#Drop empty year
World_Happiness_Life_Expectancy_df = World_Happiness_Life_Expectancy_df.replace({'NaN': None})
World_Happiness_Life_Expectancy_df_dropyear = World_Happiness_Life_Expectancy_df[World_Happiness_Life_Expectancy_df.Year.notna()]
World_Happiness_Life_Expectancy_df_dropyear.head()
# Out:
#        Country     Region_2015  Happiness_Rank_2015  Happiness_Score_2015  \
# 0  Switzerland  Western Europe                    1                 7.587
# 1      Iceland  Western Europe                    2                 7.561
# 2      Denmark  Western Europe                    3                 7.527
# 3       Norway  Western Europe                    4                 7.522
# 4       Canada   North America                    5                 7.427
#
#    Standard_Error_2015  GDP_per_Capita_2015  Family_2015  Health_2015  \
# 0              0.03411              1.39651      1.34951      0.94143
# 1              0.04884              1.30232      1.40223      0.94784
# 2              0.03328              1.32548      1.36058      0.87464
# 3              0.03880              1.45900      1.33095      0.88521
# 4              0.03553              1.32629      1.32261      0.90563
#
#    Freedom_2015  Government_Trust_2015    ...      Polio  Total expenditure  \
# 0       0.66557                0.41978    ...       97.0                NaN
# 1       0.62877                0.14145    ...       92.0                NaN
# 2       0.64938                0.48357    ...       93.0                NaN
# 3       0.66973                0.36503    ...       95.0                NaN
# 4       0.63297                0.32957    ...       91.0                NaN
#
#    Diphtheria   HIV/AIDS          GDP  Population   thinness  1-19 years  \
# 0         97.0       0.1   8989.84240   8282396.0                    0.4
# 1         92.0       0.1   5734.44360     33815.0                    1.0
# 2         93.0       0.1   5314.64416   5683483.0                    1.1
# 3         95.0       0.1   7455.24654    518867.0                    0.8
# 4         91.0       0.1  43315.74400   3584861.0                    0.6
#
#     thinness 5-9 years  Income composition of resources  Schooling
# 0                  0.3                            0.938       16.0
# 1                  0.9                            0.919       19.0
# 2                  0.9                            0.923       19.2
# 3                  0.7                            0.948       17.7
# 4                  0.5                            0.919       16.3
#
# [5 rows x 33 columns]

# %%
#Import csv data Average_usual_weekly_hours_worked_on_the_main_job.csv
weekly_hours_avg_worked_job_csv = os.path.join("Average_usual_weekly_hours_worked_on_the_main_job.csv")
weekly_hours_avg_worked_job_df = pd.read_csv(weekly_hours_avg_worked_job_csv)
weekly_hours_avg_worked_job_df_2015_2016_2017_df = weekly_hours_avg_worked_job_df.loc[weekly_hours_avg_worked_job_df['Time'] > 2015]
weekly_hours_avg_worked_job_df_2015_2016_2017_df.drop(['COUNTRY', 'SEX', 'AGE', 'EMPSTAT', 'JOBTYPE', 'FREQUENCY','Time'], axis=1, inplace=True)
weekly_hours_avg_worked_job_df_2015_2016_2017_df.head()
# Out:
# /Users/mochathereal/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#       Country          Sex       Age     Employment status  \
# 15  Australia  All persons  15 to 24  Dependent employment
# 16  Australia  All persons  15 to 24  Dependent employment
# 32  Australia  All persons  15 to 24  Dependent employment
# 33  Australia  All persons  15 to 24  Dependent employment
# 49  Australia  All persons  15 to 24  Dependent employment
#
#                      Job type Frequency  TIME Unit Code   Unit  \
# 15       Full-time employment    Annual  2016      HOUR  Hours
# 16       Full-time employment    Annual  2017      HOUR  Hours
# 32       Part-time employment    Annual  2016      HOUR  Hours
# 33       Part-time employment    Annual  2017      HOUR  Hours
# 49  Total declared employment    Annual  2016      HOUR  Hours
#
#     PowerCode Code PowerCode  Reference Period Code  Reference Period  \
# 15               0     Units                    NaN               NaN
# 16               0     Units                    NaN               NaN
# 32               0     Units                    NaN               NaN
# 33               0     Units                    NaN               NaN
# 49               0     Units                    NaN               NaN
#
#         Value  Flag Codes  Flags
# 15  39.670223         NaN    NaN
# 16  39.674686         NaN    NaN
# 32  14.072064         NaN    NaN
# 33  14.163016         NaN    NaN
# 49  27.112830         NaN    NaN

# %%
#import into DB
disk_engine = create_engine('sqlite:///World_Happiness_Life_Expectancy_db.sqlite')
World_Happiness_Life_Expectancy_df_dropyear.to_sql('World_Happiness_Life_Expectancy_tb', disk_engine, if_exists='append')
World_Happiness_Report_2015_2016_2017_df.to_sql('World_Happiness_Report_2015_2016_2017_tb', disk_engine, if_exists='append')
weekly_hours_avg_worked_job_df_2015_2016_2017_df.to_sql('weekly_hours_avg_worked_job_df_2015_2017_tb', disk_engine)

# %%
#Select from sql lite
df_sql_select_example = pd.read_sql_query('SELECT * FROM weekly_hours_avg_worked_job_df_2015_2017_tb',disk_engine)
df_sql_select_example.head()
# Out:
#    index    Country          Sex       Age     Employment status  \
# 0     15  Australia  All persons  15 to 24  Dependent employment
# 1     16  Australia  All persons  15 to 24  Dependent employment
# 2     32  Australia  All persons  15 to 24  Dependent employment
# 3     33  Australia  All persons  15 to 24  Dependent employment
# 4     49  Australia  All persons  15 to 24  Dependent employment
#
#                     Job type Frequency  TIME Unit Code   Unit  PowerCode Code  \
# 0       Full-time employment    Annual  2016      HOUR  Hours               0
# 1       Full-time employment    Annual  2017      HOUR  Hours               0
# 2       Part-time employment    Annual  2016      HOUR  Hours               0
# 3       Part-time employment    Annual  2017      HOUR  Hours               0
# 4  Total declared employment    Annual  2016      HOUR  Hours               0
#
#   PowerCode Reference Period Code Reference Period      Value Flag Codes Flags
# 0     Units                  None             None  39.670223       None  None
# 1     Units                  None             None  39.674686       None  None
# 2     Units                  None             None  14.072064       None  None
# 3     Units                  None             None  14.163016       None  None
# 4     Units                  None             None  27.112830       None  None

# %%
#create table for each happiness year
